# %%
import os
import sys
import random
import math
import numpy as np
import skimage.io
import matplotlib
import matplotlib.pyplot as plt

# Root directory of the project
ROOT_DIR = os.path.abspath("../")

# Import Mask RCNN
# sys.path.append(ROOT_DIR)  # To find local version of the library
sys.path.insert(1, (os.path.join(ROOT_DIR, 'Mask_RCNN', 'mrcnn')))
from mrcnn import utils
import mrcnn.model as modellib
from mrcnn import visualize
# Import COCO config
# sys.path.append(os.path.join(ROOT_DIR, "samples/coco/"))  # To find local version
sys.path.append(os.path.join(ROOT_DIR, 'Mask_RCNN/samples/coco'))
import coco

# %matplotlib inline 

# Directory to save logs and trained model
MODEL_DIR = os.path.join(ROOT_DIR, "Mask_RCNN/logs/")

# Local path to trained weights file
# COCO_MODEL_PATH = os.path.join(ROOT_DIR, "mask_rcnn_coco.h5")
COCO_MODEL_PATH = os.path.join(ROOT_DIR, "mask_rcnn_coco_train5_from_origin_heads_only.h5")

# Download COCO trained weights from Releases if needed
if not os.path.exists(COCO_MODEL_PATH):
    utils.download_trained_weights(COCO_MODEL_PATH)

# %%
class InferenceConfig(coco.CocoConfig):
    # Set batch size to 1 since we'll be running inference on
    # one image at a time. Batch size = GPU_COUNT * IMAGES_PER_GPU
    GPU_COUNT = 1
    IMAGES_PER_GPU = 1

config = InferenceConfig()
config.display()
# Out:
# Configurations:
# BACKBONE                       resnet101
# BACKBONE_STRIDES               [4, 8, 16, 32, 64]
# BATCH_SIZE                     1
# BBOX_STD_DEV                   [0.1 0.1 0.2 0.2]
# COMPUTE_BACKBONE_SHAPE         None
# DETECTION_MAX_INSTANCES        100
# DETECTION_MIN_CONFIDENCE       0.7
# DETECTION_NMS_THRESHOLD        0.3
# FPN_CLASSIF_FC_LAYERS_SIZE     1024
# GPU_COUNT                      1
# GRADIENT_CLIP_NORM             5.0
# IMAGES_PER_GPU                 1
# IMAGE_CHANNEL_COUNT            3
# IMAGE_MAX_DIM                  1024
# IMAGE_META_SIZE                93
# IMAGE_MIN_DIM                  800
# IMAGE_MIN_SCALE                0
# IMAGE_RESIZE_MODE              square
# IMAGE_SHAPE                    [1024 1024    3]
# LEARNING_MOMENTUM              0.9
# LEARNING_RATE                  0.001
# LOSS_WEIGHTS                   {'rpn_class_loss': 1.0, 'rpn_bbox_loss': 1.0, 'mrcnn_class_loss': 1.0, 'mrcnn_bbox_loss': 1.0, 'mrcnn_mask_loss': 1.0}
# MASK_POOL_SIZE                 14
# MASK_SHAPE                     [28, 28]
# MAX_GT_INSTANCES               100
# MEAN_PIXEL                     [123.7 116.8 103.9]
# MINI_MASK_SHAPE                (56, 56)
# NAME                           coco
# NUM_CLASSES                    81
# POOL_SIZE                      7
# POST_NMS_ROIS_INFERENCE        1000
# POST_NMS_ROIS_TRAINING         2000
# PRE_NMS_LIMIT                  6000
# ROI_POSITIVE_RATIO             0.33
# RPN_ANCHOR_RATIOS              [0.5, 1, 2]
# RPN_ANCHOR_SCALES              (32, 64, 128, 256, 512)
# RPN_ANCHOR_STRIDE              1
# RPN_BBOX_STD_DEV               [0.1 0.1 0.2 0.2]
# RPN_NMS_THRESHOLD              0.7
# RPN_TRAIN_ANCHORS_PER_IMAGE    256
# STEPS_PER_EPOCH                1000
# TOP_DOWN_PYRAMID_SIZE          256
# TRAIN_BN                       False
# TRAIN_ROIS_PER_IMAGE           200
# USE_MINI_MASK                  True
# USE_RPN_ROIS                   True
# VALIDATION_STEPS               50
# WEIGHT_DECAY                   0.0001

# %%
# Create model object in inference mode.
model = modellib.MaskRCNN(mode="inference", model_dir=MODEL_DIR, config=config)

# Load weights trained on MS-COCO
model.load_weights(COCO_MODEL_PATH, by_name=True)
# Out:
# ----------------------------debug base_layer.py 983
# str(self.name): zero_padding2d
# The caller function is 'error_handler' in module 'keras.utils.traceback_utils' (current in base_layer.py 989)
# args: (<KerasTensor: shape=(None, None, None, 3) dtype=float32 (created by layer 'input_image')>,)
# kwargs: {}
# ----------------------------debug base_layer.py 1009
# ----------------------------debug base_layer.py 1011
# ----------------------------debug base_layer.py 1013
# ----------------------------debug base_layer.py 1023
# The caller function is '_functional_construction_call' in module 'keras.engine.base_layer' (current in base_layer.py 2358)
# The caller function is '<listcomp>' in module 'tensorflow.python.util.nest' (currently in keras_tensor.py 670)
# ----------------------------debug keras_tensor.py 243
# The caller function is 'keras_tensor_to_placeholder' in module 'keras.engine.keras_tensor' (currently in keras_tensor.py 248)
# keras_tensor.py self: KerasTensor(type_spec=TensorSpec(shape=(None, None, None, 3), dtype=tf.float32, name='input_image'), name='input_image', description="created by layer 'input_image'")
# component_to_placeholder: <function KerasTensor._to_placeholder.<locals>.component_to_placeholder at 0x000001CE3B52BD00>
# self.type_spec: TensorSpec(shape=(None, None, None, 3), dtype=tf.float32, name='input_image')
# The caller function is '<listcomp>' in module 'tensorflow.python.util.nest' (current in keras.engine.keras_tensor 238)
# The caller function is 'placeholder' in module 'tensorflow.python.ops.array_ops' (current in gen_array_ops.py 6902)
# name: None
# dtype: 1
# The caller function is '<listcomp>' in module 'tensorflow.python.util.nest' (currently in keras_tensor.py 670)
# ----------------------------debug base_layer.py 2441
# ----------------------------debug traceback_utils.py 101
# The caller function is '_infer_output_signature' in module 'keras.engine.base_layer' (current in base_layer.py 989)
# ----------------------------debug base_layer.py 2462
# ----------------------------debug base_layer.py 2471
# ----------------------------debug base_layer.py 983
# str(self.name): conv1
# The caller function is 'error_handler' in module 'keras.utils.traceback_utils' (current in base_layer.py 989)
# args: (<KerasTensor: shape=(None, None, None, 3) dtype=float32 (created by layer 'zero_padding2d')>,)
# kwargs: {}
# ----------------------------debug base_layer.py 1009
# ----------------------------debug base_layer.py 1011
# ----------------------------debug base_layer.py 1013
# ----------------------------debug base_layer.py 1023
# The caller function is '_functional_construction_call' in module 'keras.engine.base_layer' (current in base_layer.py 2358)
# The caller function is '<listcomp>' in module 'tensorflow.python.util.nest' (currently in keras_tensor.py 670)
# ----------------------------debug keras_tensor.py 243
# The caller function is 'keras_tensor_to_placeholder' in module 'keras.engine.keras_tensor' (currently in keras_tensor.py 248)
# keras_tensor.py self: KerasTensor(type_spec=TensorSpec(shape=(None, None, None, 3), dtype=tf.float32, name=None), name='zero_padding2d/Pad:0', description="created by layer 'zero_padding2d'")
# component_to_placeholder: <function KerasTensor._to_placeholder.<locals>.component_to_placeholder at 0x000001CE3B52BD90>
# self.type_spec: TensorSpec(shape=(None, None, None, 3), dtype=tf.float32, name=None)
# The caller function is '<listcomp>' in module 'tensorflow.python.util.nest' (current in keras.engine.keras_tensor 238)
# The caller function is 'placeholder' in module 'tensorflow.python.ops.array_ops' (current in gen_array_ops.py 6902)
# name: None
# dtype: 1
# The caller function is '<listcomp>' in module 'tensorflow.python.util.nest' (currently in keras_tensor.py 670)
# ----------------------------debug base_layer.py 2441
# ----------------------------debug traceback_utils.py 101
# The caller function is '_infer_output_signature' in module 'keras.engine.base_layer' (current in base_layer.py 989)
# ----------------------------debug base_layer.py 2462
# ----------------------------debug base_layer.py 2471
# ----------------------------debug base_layer.py 983
# str(self.name): bn_conv1
# The caller function is 'error_handler' in module 'keras.utils.traceback_utils' (current in base_layer.py 989)
# args: (<KerasTensor: shape=(None, None, None, 64) dtype=float32 (created by layer 'conv1')>,)
# kwargs: {'training': False}
# ----------------------------debug base_layer.py 1009
# ----------------------------debug base_layer.py 1011
# ----------------------------debug base_layer.py 1013
# ----------------------------debug base_layer.py 1023
# The caller function is '_functional_construction_call' in module 'keras.engine.base_layer' (current in base_layer.py 2358)
# The caller function is '<listcomp>' in module 'tensorflow.python.util.nest' (currently in keras_tensor.py 670)
# ----------------------------debug keras_tensor.py 243
# The caller function is 'keras_tensor_to_placeholder' in module 'keras.engine.keras_tensor' (currently in keras_tensor.py 248)
# keras_tensor.py self: KerasTensor(type_spec=TensorSpec(shape=(None, None, None, 64), dtype=tf.float32, name=None), name='conv1/BiasAdd:0', description="created by layer 'conv1'")
# component_to_placeholder: <function KerasTensor._to_placeholder.<locals>.component_to_placeholder at 0x000001CE3B52BF40>
# self.type_spec: TensorSpec(shape=(None, None, None, 64), dtype=tf.float32, name=None)
# The caller function is '<listcomp>' in module 'tensorflow.python.util.nest' (current in keras.engine.keras_tensor 238)
# The caller function is 'placeholder' in module 'tensorflow.python.ops.array_ops' (current in gen_array_ops.py 6902)
# name: None
# dtype: 1
# The caller function is '<listcomp>' in module 'tensorflow.python.util.nest' (currently in keras_tensor.py 670)
# The caller function is '<listcomp>' in module 'tensorflow.python.util.nest' (currently in keras_tensor.py 670)
# ----------------------------debug base_layer.py 2441
# ----------------------------debug traceback_utils.py 101
# The caller function is '_infer_output_signature' in module 'keras.engine.base_layer' (current in base_layer.py 989)
# ----------------------------debug base_layer.py 2462
# ----------------------------debug base_layer.py 2471
# ----------------------------debug base_layer.py 983
# str(self.name): activation
# The caller function is 'error_handler' in module 'keras.utils.traceback_utils' (current in base_layer.py 989)
# args: (<KerasTensor: shape=(None, None, None, 64) dtype=float32 (created by layer 'bn_conv1')>,)
# kwargs: {}
# ----------------------------debug base_layer.py 1009
# ----------------------------debug base_layer.py 1011
# ----------------------------debug base_layer.py 1013
# ----------------------------debug base_layer.py 1023
# The caller function is '_functional_construction_call' in module 'keras.engine.base_layer' (current in base_layer.py 2358)
# The caller function is '<listcomp>' in module 'tensorflow.python.util.nest' (currently in keras_tensor.py 670)
# ----------------------------debug keras_tensor.py 243
# The caller function is 'keras_tensor_to_placeholder' in module 'keras.engine.keras_tensor' (currently in keras_tensor.py 248)
# keras_tensor.py self: KerasTensor(type_spec=TensorSpec(shape=(None, None, None, 64), dtype=tf.float32, name=None), name='bn_conv1/FusedBatchNormV3:0', description="created by layer 'bn_conv1'")
# component_to_placeholder: <function KerasTensor._to_placeholder.<locals>.component_to_placeholder at 0x000001CE3B61DD80>
# self.type_spec: TensorSpec(shape=(None, None, None, 64), dtype=tf.float32, name=None)
# The caller function is '<listcomp>' in module 'tensorflow.python.util.nest' (current in keras.engine.keras_tensor 238)
# The caller function is 'placeholder' in module 'tensorflow.python.ops.array_ops' (current in gen_array_ops.py 6902)
# name: None
# dtype: 1
# The caller function is '<listcomp>' in module 'tensorflow.python.util.nest' (currently in keras_tensor.py 670)
# ----------------------------debug base_layer.py 2441
# ----------------------------debug traceback_utils.py 101
# The caller function is '_infer_output_signature' in module 'keras.engine.base_layer' (current in base_layer.py 989)
# ----------------------------debug base_layer.py 2462
# ----------------------------debug base_layer.py 2471
# ----------------------------debug base_layer.py 983
# str(self.name): max_pooling2d
# The caller function is 'error_handler' in module 'keras.utils.traceback_utils' (current in base_layer.py 989)
# args: (<KerasTensor: shape=(None, None, None, 64) dtype=float32 (created by layer 'activation')>,)
# kwargs: {}
# ----------------------------debug base_layer.py 1009
# ----------------------------debug base_layer.py 1011
# ----------------------------debug base_layer.py 1013
# ----------------------------debug base_layer.py 1023
# The caller function is '_functional_construction_call' in module 'keras.engine.base_layer' (current in base_layer.py 2358)
# The caller function is '<listcomp>' in module 'tensorflow.python.util.nest' (currently in keras_tensor.py 670)
# ----------------------------debug keras_tensor.py 243
# The caller function is 'keras_tensor_to_placeholder' in module 'keras.engine.keras_tensor' (currently in keras_tensor.py 248)
# keras_tensor.py self: KerasTensor(type_spec=TensorSpec(shape=(None, None, None, 64), dtype=tf.float32, name=None), name='activation/Relu:0', description="created by layer 'activation'")
# component_to_placeholder: <function KerasTensor._to_placeholder.<locals>.component_to_placeholder at 0x000001CE3B61DD80>
# self.type_spec: TensorSpec(shape=(None, None, None, 64), dtype=tf.float32, name=None)
# The caller function is '<listcomp>' in module 'tensorflow.python.util.nest' (current in keras.engine.keras_tensor 238)
# The caller function is 'placeholder' in module 'tensorflow.python.ops.array_ops' (current in gen_array_ops.py 6902)
# name: None
# dtype: 1
# The caller function is '<listcomp>' in module 'tensorflow.python.util.nest' (currently in keras_tensor.py 670)
# ----------------------------debug base_layer.py 2441
# ----------------------------debug traceback_utils.py 101
# The caller function is '_infer_output_signature' in module 'keras.engine.base_layer' (current in base_layer.py 989)
# ----------------------------debug base_layer.py 2462
# ----------------------------debug base_layer.py 2471
# ----------------------------debug base_layer.py 983
# str(self.name): res2a_branch2a
# The caller function is 'error_handler' in module 'keras.utils.traceback_utils' (current in base_layer.py 989)
# args: (<KerasTensor: shape=(None, None, None, 64) dtype=float32 (created by layer 'max_pooling2d')>,)
# kwargs: {}
# ----------------------------debug base_layer.py 1009
# ----------------------------debug base_layer.py 1011
# ----------------------------debug base_layer.py 1013
# ----------------------------debug base_layer.py 1023
# The caller function is '_functional_construction_call' in module 'keras.engine.base_layer' (current in base_layer.py 2358)
# The caller function is '<listcomp>' in module 'tensorflow.python.util.nest' (currently in keras_tensor.py 670)
# ----------------------------debug keras_tensor.py 243
# The caller function is 'keras_tensor_to_placeholder' in module 'keras.engine.keras_tensor' (currently in keras_tensor.py 248)
# keras_tensor.py self: KerasTensor(type_spec=TensorSpec(shape=(None, None, None, 64), dtype=tf.float32, name=None), name='max_pooling2d/MaxPool:0', description="created by layer 'max_pooling2d'")
# component_to_placeholder: <function KerasTensor._to_placeholder.<locals>.component_to_placeholder at 0x000001CE3B61DD80>
# self.type_spec: TensorSpec(shape=(None, None, None, 64), dtype=tf.float32, name=None)
# The caller function is '<listcomp>' in module 'tensorflow.python.util.nest' (current in keras.engine.keras_tensor 238)
# The caller function is 'placeholder' in module 'tensorflow.python.ops.array_ops' (current in gen_array_ops.py 6902)
# name: None
# dtype: 1
# The caller function is '<listcomp>' in module 'tensorflow.python.util.nest' (currently in keras_tensor.py 670)
# ----------------------------debug base_layer.py 2441
# ----------------------------debug traceback_utils.py 101
# The caller function is '_infer_output_signature' in module 'keras.engine.base_layer' (current in base_layer.py 989)
# ----------------------------debug base_layer.py 2462
# ----------------------------debug base_layer.py 2471
# ----------------------------debug base_layer.py 983
# str(self.name): bn2a_branch2a
# The caller function is 'error_handler' in module 'keras.utils.traceback_utils' (current in base_layer.py 989)
# args: (<KerasTensor: shape=(None, None, None, 64) dtype=float32 (created by layer 'res2a_branch2a')>,)
# kwargs: {'training': False}
# ----------------------------debug base_layer.py 1009
# ----------------------------debug base_layer.py 1011
# ----------------------------debug base_layer.py 1013
# ----------------------------debug base_layer.py 1023
# The caller function is '_functional_construction_call' in module 'keras.engine.base_layer' (current in base_layer.py 2358)
# The caller function is '<listcomp>' in module 'tensorflow.python.util.nest' (currently in keras_tensor.py 670)
# ----------------------------debug keras_tensor.py 243
# The caller function is 'keras_tensor_to_placeholder' in module 'keras.engine.keras_tensor' (currently in keras_tensor.py 248)
# keras_tensor.py self: KerasTensor(type_spec=TensorSpec(shape=(None, None, None, 64), dtype=tf.float32, name=None), name='res2a_branch2a/BiasAdd:0', description="created by layer 'res2a_branch2a'")
# component_to_placeholder: <function KerasTensor._to_placeholder.<locals>.component_to_placeholder at 0x000001CE3B61DC60>
# self.type_spec: TensorSpec(shape=(None, None, None, 64), dtype=tf.float32, name=None)
# The caller function is '<listcomp>' in module 'tensorflow.python.util.nest' (current in keras.engine.keras_tensor 238)
# The caller function is 'placeholder' in module 'tensorflow.python.ops.array_ops' (current in gen_array_ops.py 6902)
# name: None
# dtype: 1
# The caller function is '<listcomp>' in module 'tensorflow.python.util.nest' (currently in keras_tensor.py 670)
# The caller function is '<listcomp>' in module 'tensorflow.python.util.nest' (currently in keras_tensor.py 670)
# ----------------------------debug base_layer.py 2441
# ----------------------------debug traceback_utils.py 101
# The caller function is '_infer_output_signature' in module 'keras.engine.base_layer' (current in base_layer.py 989)
# ----------------------------debug base_layer.py 2462
# ----------------------------debug base_layer.py 2471
# ----------------------------debug base_layer.py 983
# str(self.name): activation_1
# The caller function is 'error_handler' in module 'keras.utils.traceback_utils' (current in base_layer.py 989)
# args: (<KerasTensor: shape=(None, None, None, 64) dtype=float32 (created by layer 'bn2a_branch2a')>,)
# kwargs: {}
# ----------------------------debug base_layer.py 1009
# ----------------------------debug base_layer.py 1011
# ----------------------------debug base_layer.py 1013
# ----------------------------debug base_layer.py 1023
# The caller function is '_functional_construction_call' in module 'keras.engine.base_layer' (current in base_layer.py 2358)
# The caller function is '<listcomp>' in module 'tensorflow.python.util.nest' (currently in keras_tensor.py 670)
# ----------------------------debug keras_tensor.py 243
# The caller function is 'keras_tensor_to_placeholder' in module 'keras.engine.keras_tensor' (currently in keras_tensor.py 248)
# keras_tensor.py self: KerasTensor(type_spec=TensorSpec(shape=(None, None, None, 64), dtype=tf.float32, name=None), name='bn2a_branch2a/FusedBatchNormV3:0', description="created by layer 'bn2a_branch2a'")
# component_to_placeholder: <function KerasTensor._to_placeholder.<locals>.component_to_placeholder at 0x000001CE3B61DD80>
# self.type_spec: TensorSpec(shape=(None, None, None, 64), dtype=tf.float32, name=None)
# The caller function is '<listcomp>' in module 'tensorflow.python.util.nest' (current in keras.engine.keras_tensor 238)
# The caller function is 'placeholder' in module 'tensorflow.python.ops.array_ops' (current in gen_array_ops.py 6902)
# name: None
# dtype: 1
# The caller function is '<listcomp>' in module 'tensorflow.python.util.nest' (currently in keras_tensor.py 670)
# ----------------------------debug base_layer.py 2441
# ----------------------------debug traceback_utils.py 101
# The caller function is '_infer_output_signature' in module 'keras.engine.base_layer' (current in base_layer.py 989)
# ----------------------------debug base_layer.py 2462
# ----------------------------debug base_layer.py 2471
# ----------------------------debug base_layer.py 983
# str(self.name): res2a_branch2b
# The caller function is 'error_handler' in module 'keras.utils.traceback_utils' (current in base_layer.py 989)
# args: (<KerasTensor: shape=(None, None, None, 64) dtype=float32 (created by layer 'activation_1')>,)
# kwargs: {}
# ----------------------------debug base_layer.py 1009
# ----------------------------debug base_layer.py 1011
# ----------------------------debug base_layer.py 1013
# ----------------------------debug base_layer.py 1023
# The caller function is '_functional_construction_call' in module 'keras.engine.base_layer' (current in base_layer.py 2358)
# The caller function is '<listcomp>' in module 'tensorflow.python.util.nest' (currently in keras_tensor.py 670)
# ----------------------------debug keras_tensor.py 243
# The caller function is 'keras_tensor_to_placeholder' in module 'keras.engine.keras_tensor' (currently in keras_tensor.py 248)
# keras_tensor.py self: KerasTensor(type_spec=TensorSpec(shape=(None, None, None, 64), dtype=tf.float32, name=None), name='activation_1/Relu:0', description="created by layer 'activation_1'")
# component_to_placeholder: <function KerasTensor._to_placeholder.<locals>.component_to_placeholder at 0x000001CE3B61DD80>
# self.type_spec: TensorSpec(shape=(None, None, None, 64), dtype=tf.float32, name=None)
# The caller function is '<listcomp>' in module 'tensorflow.python.util.nest' (current in keras.engine.keras_tensor 238)
# The caller function is 'placeholder' in module 'tensorflow.python.ops.array_ops' (current in gen_array_ops.py 6902)
# name: None
# dtype: 1
# The caller function is '<listcomp>' in module 'tensorflow.python.util.nest' (currently in keras_tensor.py 670)
# ----------------------------debug base_layer.py 2441
# ----------------------------debug traceback_utils.py 101
# The caller function is '_infer_output_signature' in module 'keras.engine.base_layer' (current in base_layer.py 989)
# ----------------------------debug base_layer.py 2462
# ----------------------------debug base_layer.py 2471
# ----------------------------debug base_layer.py 983
# str(self.name): bn2a_branch2b
# The caller function is 'error_handler' in module 'keras.utils.traceback_utils' (current in base_layer.py 989)
# args: (<KerasTensor: shape=(None, None, None, 64) dtype=float32 (created by layer 'res2a_branch2b')>,)
# kwargs: {'training': False}
# ----------------------------debug base_layer.py 1009
# ----------------------------debug base_layer.py 1011
# ----------------------------debug base_layer.py 1013
# ----------------------------debug base_layer.py 1023
# The caller function is '_functional_construction_call' in module 'keras.engine.base_layer' (current in base_layer.py 2358)
# The caller function is '<listcomp>' in module 'tensorflow.python.util.nest' (currently in keras_tensor.py 670)
# ----------------------------debug keras_tensor.py 243
# The caller function is 'keras_tensor_to_placeholder' in module 'keras.engine.keras_tensor' (currently in keras_tensor.py 248)
# keras_tensor.py self: KerasTensor(type_spec=TensorSpec(shape=(None, None, None, 64), dtype=tf.float32, name=None), name='res2a_branch2b/BiasAdd:0', description="created by layer 'res2a_branch2b'")
# component_to_placeholder: <function KerasTensor._to_placeholder.<locals>.component_to_placeholder at 0x000001CE3B61E560>
# self.type_spec: TensorSpec(shape=(None, None, None, 64), dtype=tf.float32, name=None)
# The caller function is '<listcomp>' in module 'tensorflow.python.util.nest' (current in keras.engine.keras_tensor 238)
# The caller function is 'placeholder' in module 'tensorflow.python.ops.array_ops' (current in gen_array_ops.py 6902)
# name: None
# dtype: 1
# The caller function is '<listcomp>' in module 'tensorflow.python.util.nest' (currently in keras_tensor.py 670)
# The caller function is '<listcomp>' in module 'tensorflow.python.util.nest' (currently in keras_tensor.py 670)
# ----------------------------debug base_layer.py 2441
# ----------------------------debug traceback_utils.py 101
# The caller function is '_infer_output_signature' in module 'keras.engine.base_layer' (current in base_layer.py 989)
# ----------------------------debug base_layer.py 2462
# ----------------------------debug base_layer.py 2471
# ----------------------------debug base_layer.py 983
# str(self.name): activation_2
# The caller function is 'error_handler' in module 'keras.utils.traceback_utils' (current in base_layer.py 989)
# args: (<KerasTensor: shape=(None, None, None, 64) dtype=float32 (created by layer 'bn2a_branch2b')>,)
# kwargs: {}
# ----------------------------debug base_layer.py 1009
# ----------------------------debug base_layer.py 1011
# ----------------------------debug base_layer.py 1013
# ----------------------------debug base_layer.py 1023
# The caller function is '_functional_construction_call' in module 'keras.engine.base_layer' (current in base_layer.py 2358)
# The caller function is '<listcomp>' in module 'tensorflow.python.util.nest' (currently in keras_tensor.py 670)
# ----------------------------debug keras_tensor.py 243
# The caller function is 'keras_tensor_to_placeholder' in module 'keras.engine.keras_tensor' (currently in keras_tensor.py 248)
# keras_tensor.py self: KerasTensor(type_spec=TensorSpec(shape=(None, None, None, 64), dtype=tf.float32, name=None), name='bn2a_branch2b/FusedBatchNormV3:0', description="created by layer 'bn2a_branch2b'")
# component_to_placeholder: <function KerasTensor._to_placeholder.<locals>.component_to_placeholder at 0x000001CE3B61DFC0>
# self.type_spec: TensorSpec(shape=(None, None, None, 64), dtype=tf.float32, name=None)
# The caller function is '<listcomp>' in module 'tensorflow.python.util.nest' (current in keras.engine.keras_tensor 238)
# The caller function is 'placeholder' in module 'tensorflow.python.ops.array_ops' (current in gen_array_ops.py 6902)
# name: None
# dtype: 1
# The caller function is '<listcomp>' in module 'tensorflow.python.util.nest' (currently in keras_tensor.py 670)
# ----------------------------debug base_layer.py 2441
# ----------------------------debug traceback_utils.py 101
# The caller function is '_infer_output_signature' in module 'keras.engine.base_layer' (current in base_layer.py 989)
# ----------------------------debug base_layer.py 2462
# ----------------------------debug base_layer.py 2471
# ----------------------------debug base_layer.py 983
# str(self.name): res2a_branch2c
# The caller function is 'error_handler' in module 'keras.utils.traceback_utils' (current in base_layer.py 989)
# args: (<KerasTensor: shape=(None, None, None, 64) dtype=float32 (created by layer 'activation_2')>,)
# kwargs: {}
# ----------------------------debug base_layer.py 1009
# ----------------------------debug base_layer.py 1011
# ----------------------------debug base_layer.py 1013
# ----------------------------debug base_layer.py 1023
# The caller function is '_functional_construction_call' in module 'keras.engine.base_layer' (current in base_layer.py 2358)
# The caller function is '<listcomp>' in module 'tensorflow.python.util.nest' (currently in keras_tensor.py 670)
# ----------------------------debug keras_tensor.py 243
# The caller function is 'keras_tensor_to_placeholder' in module 'keras.engine.keras_tensor' (currently in keras_tensor.py 248)
# keras_tensor.py self: KerasTensor(type_spec=TensorSpec(shape=(None, None, None, 64), dtype=tf.float32, name=None), name='activation_2/Relu:0', description="created by layer 'activation_2'")
# component_to_placeholder: <function KerasTensor._to_placeholder.<locals>.component_to_placeholder at 0x000001CE3B61DD80>
# self.type_spec: TensorSpec(shape=(None, None, None, 64), dtype=tf.float32, name=None)
# The caller function is '<listcomp>' in module 'tensorflow.python.util.nest' (current in keras.engine.keras_tensor 238)
# The caller function is 'placeholder' in module 'tensorflow.python.ops.array_ops' (current in gen_array_ops.py 6902)
# name: None
# dtype: 1
# The caller function is '<listcomp>' in module 'tensorflow.python.util.nest' (currently in keras_tensor.py 670)
# ----------------------------debug base_layer.py 2441
# ----------------------------debug traceback_utils.py 101
# The caller function is '_infer_output_signature' in module 'keras.engine.base_layer' (current in base_layer.py 989)
# ----------------------------debug base_layer.py 2462
# ----------------------------debug base_layer.py 2471
# ----------------------------debug base_layer.py 983
# str(self.name): bn2a_branch2c
# The caller function is 'error_handler' in module 'keras.utils.traceback_utils' (current in base_layer.py 989)
# args: (<KerasTensor: shape=(None, None, None, 256) dtype=float32 (created by layer 'res2a_branch2c')>,)
# kwargs: {'training': False}
# ----------------------------debug base_layer.py 1009
# ----------------------------debug base_layer.py 1011
# ----------------------------debug base_layer.py 1013
# ----------------------------debug base_layer.py 1023
# The caller function is '_functional_construction_call' in module 'keras.engine.base_layer' (current in base_layer.py 2358)
# The caller function is '<listcomp>' in module 'tensorflow.python.util.nest' (currently in keras_tensor.py 670)
# ----------------------------debug keras_tensor.py 243
# The caller function is 'keras_tensor_to_placeholder' in module 'keras.engine.keras_tensor' (currently in keras_tensor.py 248)
# keras_tensor.py self: KerasTensor(type_spec=TensorSpec(shape=(None, None, None, 256), dtype=tf.float32, name=None), name='res2a_branch2c/BiasAdd:0', description="created by layer 'res2a_branch2c'")
# component_to_placeholder: <function KerasTensor._to_placeholder.<locals>.component_to_placeholder at 0x000001CE3B61E440>
# self.type_spec: TensorSpec(shape=(None, None, None, 256), dtype=tf.float32, name=None)
# The caller function is '<listcomp>' in module 'tensorflow.python.util.nest' (current in keras.engine.keras_tensor 238)
# The caller function is 'placeholder' in module 'tensorflow.python.ops.array_ops' (current in gen_array_ops.py 6902)
# name: None
# dtype: 1
# The caller function is '<listcomp>' in module 'tensorflow.python.util.nest' (currently in keras_tensor.py 670)
# The caller function is '<listcomp>' in module 'tensorflow.python.util.nest' (currently in keras_tensor.py 670)
# ----------------------------debug base_layer.py 2441
# ----------------------------debug traceback_utils.py 101
# The caller function is '_infer_output_signature' in module 'keras.engine.base_layer' (current in base_layer.py 989)
# ----------------------------debug base_layer.py 2462
# ----------------------------debug base_layer.py 2471
# ----------------------------debug base_layer.py 983
# str(self.name): res2a_branch1
# The caller function is 'error_handler' in module 'keras.utils.traceback_utils' (current in base_layer.py 989)
# args: (<KerasTensor: shape=(None, None, None, 64) dtype=float32 (created by layer 'max_pooling2d')>,)
# kwargs: {}
# ----------------------------debug base_layer.py 1009
# ----------------------------debug base_layer.py 1011
# ----------------------------debug base_layer.py 1013
# ----------------------------debug base_layer.py 1023
# The caller function is '_functional_construction_call' in module 'keras.engine.base_layer' (current in base_layer.py 2358)
# The caller function is '<listcomp>' in module 'tensorflow.python.util.nest' (currently in keras_tensor.py 670)
# ----------------------------debug keras_tensor.py 243
# The caller function is 'keras_tensor_to_placeholder' in module 'keras.engine.keras_tensor' (currently in keras_tensor.py 248)
# keras_tensor.py self: KerasTensor(type_spec=TensorSpec(shape=(None, None, None, 64), dtype=tf.float32, name=None), name='max_pooling2d/MaxPool:0', description="created by layer 'max_pooling2d'")
# component_to_placeholder: <function KerasTensor._to_placeholder.<locals>.component_to_placeholder at 0x000001CE3B61DFC0>
# self.type_spec: TensorSpec(shape=(None, None, None, 64), dtype=tf.float32, name=None)
# The caller function is '<listcomp>' in module 'tensorflow.python.util.nest' (current in keras.engine.keras_tensor 238)
# The caller function is 'placeholder' in module 'tensorflow.python.ops.array_ops' (current in gen_array_ops.py 6902)
# name: None
# dtype: 1
# The caller function is '<listcomp>' in module 'tensorflow.python.util.nest' (currently in keras_tensor.py 670)
# ----------------------------debug base_layer.py 2441
# ----------------------------debug traceback_utils.py 101
# The caller function is '_infer_output_signature' in module 'keras.engine.base_layer' (current in base_layer.py 989)
# ----------------------------debug base_layer.py 2462
# ----------------------------debug base_layer.py 2471
# ----------------------------debug base_layer.py 983
# str(self.name): bn2a_branch1
# The caller function is 'error_handler' in module 'keras.utils.traceback_utils' (current in base_layer.py 989)
# args: (<KerasTensor: shape=(None, None, None, 256) dtype=float32 (created by layer 'res2a_branch1')>,)
# kwargs: {'training': False}
# ----------------------------debug base_layer.py 1009
# ----------------------------debug base_layer.py 1011
# ----------------------------debug base_layer.py 1013
# ----------------------------debug base_layer.py 1023
# The caller function is '_functional_construction_call' in module 'keras.engine.base_layer' (current in base_layer.py 2358)
# The caller function is '<listcomp>' in module 'tensorflow.python.util.nest' (currently in keras_tensor.py 670)
# ----------------------------debug keras_tensor.py 243
# The caller function is 'keras_tensor_to_placeholder' in module 'keras.engine.keras_tensor' (currently in keras_tensor.py 248)
# keras_tensor.py self: KerasTensor(type_spec=TensorSpec(shape=(None, None, None, 256), dtype=tf.float32, name=None), name='res2a_branch1/BiasAdd:0', description="created by layer 'res2a_branch1'")
# component_to_placeholder: <function KerasTensor._to_placeholder.<locals>.component_to_placeholder at 0x000001CE3B61DCF0>
# self.type_spec: TensorSpec(shape=(None, None, None, 256), dtype=tf.float32, name=None)
# The caller function is '<listcomp>' in module 'tensorflow.python.util.nest' (current in keras.engine.keras_tensor 238)
# The caller function is 'placeholder' in module 'tensorflow.python.ops.array_ops' (current in gen_array_ops.py 6902)
# name: None
# dtype: 1
# The caller function is '<listcomp>' in module 'tensorflow.python.util.nest' (currently in keras_tensor.py 670)
# The caller function is '<listcomp>' in module 'tensorflow.python.util.nest' (currently in keras_tensor.py 670)
# ----------------------------debug base_layer.py 2441
# ----------------------------debug traceback_utils.py 101
# The caller function is '_infer_output_signature' in module 'keras.engine.base_layer' (current in base_layer.py 989)
# ----------------------------debug base_layer.py 2462
# ----------------------------debug base_layer.py 2471
# ----------------------------debug base_layer.py 983
# str(self.name): add
# The caller function is 'error_handler' in module 'keras.utils.traceback_utils' (current in base_layer.py 989)
# args: ([<KerasTensor: shape=(None, None, None, 256) dtype=float32 (created by layer 'bn2a_branch2c')>, <KerasTensor: shape=(None, None, None, 256) dtype=float32 (created by layer 'bn2a_branch1')>],)
# kwargs: {}
# ----------------------------debug base_layer.py 1009
# ----------------------------debug base_layer.py 1011
# ----------------------------debug base_layer.py 1013
# ----------------------------debug base_layer.py 1023
# The caller function is '_functional_construction_call' in module 'keras.engine.base_layer' (current in base_layer.py 2358)
# The caller function is '<listcomp>' in module 'tensorflow.python.util.nest' (currently in keras_tensor.py 670)
# ----------------------------debug keras_tensor.py 243
# The caller function is 'keras_tensor_to_placeholder' in module 'keras.engine.keras_tensor' (currently in keras_tensor.py 248)
# keras_tensor.py self: KerasTensor(type_spec=TensorSpec(shape=(None, None, None, 256), dtype=tf.float32, name=None), name='bn2a_branch2c/FusedBatchNormV3:0', description="created by layer 'bn2a_branch2c'")
# component_to_placeholder: <function KerasTensor._to_placeholder.<locals>.component_to_placeholder at 0x000001CE3B61DD80>
# self.type_spec: TensorSpec(shape=(None, None, None, 256), dtype=tf.float32, name=None)
# The caller function is '<listcomp>' in module 'tensorflow.python.util.nest' (current in keras.engine.keras_tensor 238)
# The caller function is 'placeholder' in module 'tensorflow.python.ops.array_ops' (current in gen_array_ops.py 6902)
# name: None
# dtype: 1
# The caller function is '<listcomp>' in module 'tensorflow.python.util.nest' (currently in keras_tensor.py 670)
# ----------------------------debug keras_tensor.py 243
# The caller function is 'keras_tensor_to_placeholder' in module 'keras.engine.keras_tensor' (currently in keras_tensor.py 248)
# keras_tensor.py self: KerasTensor(type_spec=TensorSpec(shape=(None, None, None, 256), dtype=tf.float32, name=None), name='bn2a_branch1/FusedBatchNormV3:0', description="created by layer 'bn2a_branch1'")
# component_to_placeholder: <function KerasTensor._to_placeholder.<locals>.component_to_placeholder at 0x000001CE3B61DD80>
# self.type_spec: TensorSpec(shape=(None, None, None, 256), dtype=tf.float32, name=None)
# The caller function is '<listcomp>' in module 'tensorflow.python.util.nest' (current in keras.engine.keras_tensor 238)
# The caller function is 'placeholder' in module 'tensorflow.python.ops.array_ops' (current in gen_array_ops.py 6902)
# name: None
# dtype: 1
# The caller function is '<listcomp>' in module 'tensorflow.python.util.nest' (currently in keras_tensor.py 670)
# ----------------------------debug base_layer.py 2441
# ----------------------------debug traceback_utils.py 101
# The caller function is '_infer_output_signature' in module 'keras.engine.base_layer' (current in base_layer.py 989)
# ----------------------------debug base_layer.py 2462
# ----------------------------debug base_layer.py 2471
# ----------------------------debug base_layer.py 983
# str(self.name): res2a_out
# The caller function is 'error_handler' in module 'keras.utils.traceback_utils' (current in base_layer.py 989)
# args: (<KerasTensor: shape=(None, None, None, 256) dtype=float32 (created by layer 'add')>,)
# kwargs: {}
# ----------------------------debug base_layer.py 1009
# ----------------------------debug base_layer.py 1011
# ----------------------------debug base_layer.py 1013
# ----------------------------debug base_layer.py 1023
# The caller function is '_functional_construction_call' in module 'keras.engine.base_layer' (current in base_layer.py 2358)
# The caller function is '<listcomp>' in module 'tensorflow.python.util.nest' (currently in keras_tensor.py 670)
# ----------------------------debug keras_tensor.py 243
# The caller function is 'keras_tensor_to_placeholder' in module 'keras.engine.keras_tensor' (currently in keras_tensor.py 248)
# keras_tensor.py self: KerasTensor(type_spec=TensorSpec(shape=(None, None, None, 256), dtype=tf.float32, name=None), name='add/add:0', description="created by layer 'add'")
# component_to_placeholder: <function KerasTensor._to_placeholder.<locals>.component_to_placeholder at 0x000001CE3B61DFC0>
# self.type_spec: TensorSpec(shape=(None, None, None, 256), dtype=tf.float32, name=None)
# The caller function is '<listcomp>' in module 'tensorflow.python.util.nest' (current in keras.engine.keras_tensor 238)
# The caller function is 'placeholder' in module 'tensorflow.python.ops.array_ops' (current in gen_array_ops.py 6902)
# name: None
# dtype: 1
# The caller function is '<listcomp>' in module 'tensorflow.python.util.nest' (currently in keras_tensor.py 670)
# ----------------------------debug base_layer.py 2441
# ----------------------------debug traceback_utils.py 101
# The caller function is '_infer_output_signature' in module 'keras.engine.base_layer' (current in base_layer.py 989)
# ----------------------------debug base_layer.py 2462
# ----------------------------debug base_layer.py 2471
# ----------------------------debug base_layer.py 983
# str(self.name): res2b_branch2a
# The caller function is 'error_handler' in module 'keras.utils.traceback_utils' (current in base_layer.py 989)
# args: (<KerasTensor: shape=(None, None, None, 256) dtype=float32 (created by layer 'res2a_out')>,)
# kwargs: {}
# ----------------------------debug base_layer.py 1009
# ----------------------------debug base_layer.py 1011
# ----------------------------debug base_layer.py 1013
# ----------------------------debug base_layer.py 1023
# The caller function is '_functional_construction_call' in module 'keras.engine.base_layer' (current in base_layer.py 2358)
# The caller function is '<listcomp>' in module 'tensorflow.python.util.nest' (currently in keras_tensor.py 670)
# ----------------------------debug keras_tensor.py 243
# The caller function is 'keras_tensor_to_placeholder' in module 'keras.engine.keras_tensor' (currently in keras_tensor.py 248)
# keras_tensor.py self: KerasTensor(type_spec=TensorSpec(shape=(None, None, None, 256), dtype=tf.float32, name=None), name='res2a_out/Relu:0', description="created by layer 'res2a_out'")
# component_to_placeholder: <function KerasTensor._to_placeholder.<locals>.component_to_placeholder at 0x000001CE3B61E050>
# self.type_spec: TensorSpec(shape=(None, None, None, 256), dtype=tf.float32, name=None)
# The caller function is '<listcomp>' in module 'tensorflow.python.util.nest' (current in keras.engine.keras_tensor 238)
# The caller function is 'placeholder' in module 'tensorflow.python.ops.array_ops' (current in gen_array_ops.py 6902)
# name: None
# dtype: 1
# The caller function is '<listcomp>' in module 'tensorflow.python.util.nest' (currently in keras_tensor.py 670)
# ----------------------------debug base_layer.py 2441
# ----------------------------debug traceback_utils.py 101
# The caller function is '_infer_output_signature' in module 'keras.engine.base_layer' (current in base_layer.py 989)
# ----------------------------debug base_layer.py 2462
# ----------------------------debug base_layer.py 2471
# ----------------------------debug base_layer.py 983
# str(self.name): bn2b_branch2a
# The caller function is 'error_handler' in module 'keras.utils.traceback_utils' (current in base_layer.py 989)
# args: (<KerasTensor: shape=(None, None, None, 64) dtype=float32 (created by layer 'res2b_branch2a')>,)
# kwargs: {'training': False}
# ----------------------------debug base_layer.py 1009
# ----------------------------debug base_layer.py 1011
# ----------------------------debug base_layer.py 1013
# ----------------------------debug base_layer.py 1023
# The caller function is '_functional_construction_call' in module 'keras.engine.base_layer' (current in base_layer.py 2358)
# The caller function is '<listcomp>' in module 'tensorflow.python.util.nest' (currently in keras_tensor.py 670)
# ----------------------------debug keras_tensor.py 243
# The caller function is 'keras_tensor_to_placeholder' in module 'keras.engine.keras_tensor' (currently in keras_tensor.py 248)
# keras_tensor.py self: KerasTensor(type_spec=TensorSpec(shape=(None, None, None, 64), dtype=tf.float32, name=None), name='res2b_branch2a/BiasAdd:0', description="created by layer 'res2b_branch2a'")
# component_to_placeholder: <function KerasTensor._to_placeholder.<locals>.component_to_placeholder at 0x000001CE3B61DB40>
# self.type_spec: TensorSpec(shape=(None, None, None, 64), dtype=tf.float32, name=None)
# The caller function is '<listcomp>' in module 'tensorflow.python.util.nest' (current in keras.engine.keras_tensor 238)
# The caller function is 'placeholder' in module 'tensorflow.python.ops.array_ops' (current in gen_array_ops.py 6902)
# name: None
# dtype: 1
# The caller function is '<listcomp>' in module 'tensorflow.python.util.nest' (currently in keras_tensor.py 670)
# The caller function is '<listcomp>' in module 'tensorflow.python.util.nest' (currently in keras_tensor.py 670)
# ----------------------------debug base_layer.py 2441
# ----------------------------debug traceback_utils.py 101
# The caller function is '_infer_output_signature' in module 'keras.engine.base_layer' (current in base_layer.py 989)
# ----------------------------debug base_layer.py 2462
# ----------------------------debug base_layer.py 2471
# ----------------------------debug base_layer.py 983
# str(self.name): activation_3
# The caller function is 'error_handler' in module 'keras.utils.traceback_utils' (current in base_layer.py 989)
# args: (<KerasTensor: shape=(None, None, None, 64) dtype=float32 (created by layer 'bn2b_branch2a')>,)
# kwargs: {}
# ----------------------------debug base_layer.py 1009
# ----------------------------debug base_layer.py 1011
# ----------------------------debug base_layer.py 1013
# ----------------------------debug base_layer.py 1023
# The caller function is '_functional_construction_call' in module 'keras.engine.base_layer' (current in base_layer.py 2358)
# The caller function is '<listcomp>' in module 'tensorflow.python.util.nest' (currently in keras_tensor.py 670)
# ----------------------------debug keras_tensor.py 243
# The caller function is 'keras_tensor_to_placeholder' in module 'keras.engine.keras_tensor' (currently in keras_tensor.py 248)
# keras_tensor.py self: KerasTensor(type_spec=TensorSpec(shape=(None, None, None, 64), dtype=tf.float32, name=None), name='bn2b_branch2a/FusedBatchNormV3:0', description="created by layer 'bn2b_branch2a'")
# component_to_placeholder: <function KerasTensor._to_placeholder.<locals>.component_to_placeholder at 0x000001CE3B61DFC0>
# self.type_spec: TensorSpec(shape=(None, None, None, 64), dtype=tf.float32, name=None)
# The caller function is '<listcomp>' in module 'tensorflow.python.util.nest' (current in keras.engine.keras_tensor 238)
# The caller function is 'placeholder' in module 'tensorflow.python.ops.array_ops' (current in gen_array_ops.py 6902)
# name: None
# dtype: 1
# The caller function is '<listcomp>' in module 'tensorflow.python.util.nest' (currently in keras_tensor.py 670)
# ----------------------------debug base_layer.py 2441
# ----------------------------debug traceback_utils.py 101
# The caller function is '_infer_output_signature' in module 'keras.engine.base_layer' (current in base_layer.py 989)
# ----------------------------debug base_layer.py 2462
# ----------------------------debug base_layer.py 2471
# ----------------------------debug base_layer.py 983
# str(self.name): res2b_branch2b
# The caller function is 'error_handler' in module 'keras.utils.traceback_utils' (current in base_layer.py 989)
# args: (<KerasTensor: shape=(None, None, None, 64) dtype=float32 (created by layer 'activation_3')>,)
# kwargs: {}
# ----------------------------debug base_layer.py 1009
# ----------------------------debug base_layer.py 1011
# ----------------------------debug base_layer.py 1013
# ----------------------------debug base_layer.py 1023
# The caller function is '_functional_construction_call' in module 'keras.engine.base_layer' (current in base_layer.py 2358)
# The caller function is '<listcomp>' in module 'tensorflow.python.util.nest' (currently in keras_tensor.py 670)
# ----------------------------debug keras_tensor.py 243
# The caller function is 'keras_tensor_to_placeholder' in module 'keras.engine.keras_tensor' (currently in keras_tensor.py 248)
# keras_tensor.py self: KerasTensor(type_spec=TensorSpec(shape=(None, None, None, 64), dtype=tf.float32, name=None), name='activation_3/Relu:0', description="created by layer 'activation_3'")
# component_to_placeholder: <function KerasTensor._to_placeholder.<locals>.component_to_placeholder at 0x000001CE3B61E050>
# self.type_spec: TensorSpec(shape=(None, None, None, 64), dtype=tf.float32, name=None)
# The caller function is '<listcomp>' in module 'tensorflow.python.util.nest' (current in keras.engine.keras_tensor 238)
# The caller function is 'placeholder' in module 'tensorflow.python.ops.array_ops' (current in gen_array_ops.py 6902)
# name: None
# dtype: 1
# The caller function is '<listcomp>' in module 'tensorflow.python.util.nest' (currently in keras_tensor.py 670)
# ----------------------------debug base_layer.py 2441
# ----------------------------debug traceback_utils.py 101
# The caller function is '_infer_output_signature' in module 'keras.engine.base_layer' (current in base_layer.py 989)
# ----------------------------debug base_layer.py 2462
# ----------------------------debug base_layer.py 2471
# ----------------------------debug base_layer.py 983
# str(self.name): bn2b_branch2b
# The caller function is 'error_handler' in module 'keras.utils.traceback_utils' (current in base_layer.py 989)
# args: (<KerasTensor: shape=(None, None, None, 64) dtype=float32 (created by layer 'res2b_branch2b')>,)
# kwargs: {'training': False}
# ----------------------------debug base_layer.py 1009
# ----------------------------debug base_layer.py 1011
# ----------------------------debug base_layer.py 1013
# ----------------------------debug base_layer.py 1023
# The caller function is '_functional_construction_call' in module 'keras.engine.base_layer' (current in base_layer.py 2358)
# The caller function is '<listcomp>' in module 'tensorflow.python.util.nest' (currently in keras_tensor.py 670)
# ----------------------------debug keras_tensor.py 243
# The caller function is 'keras_tensor_to_placeholder' in module 'keras.engine.keras_tensor' (currently in keras_tensor.py 248)
# keras_tensor.py self: KerasTensor(type_spec=TensorSpec(shape=(None, None, None, 64), dtype=tf.float32, name=None), name='res2b_branch2b/BiasAdd:0', description="created by layer 'res2b_branch2b'")
# component_to_placeholder: <function KerasTensor._to_placeholder.<locals>.component_to_placeholder at 0x000001CE3B61E680>
# self.type_spec: TensorSpec(shape=(None, None, None, 64), dtype=tf.float32, name=None)
# The caller function is '<listcomp>' in module 'tensorflow.python.util.nest' (current in keras.engine.keras_tensor 238)
# The caller function is 'placeholder' in module 'tensorflow.python.ops.array_ops' (current in gen_array_ops.py 6902)
# name: None
# dtype: 1
# The caller function is '<listcomp>' in module 'tensorflow.python.util.nest' (currently in keras_tensor.py 670)
# The caller function is '<listcomp>' in module 'tensorflow.python.util.nest' (currently in keras_tensor.py 670)
# ----------------------------debug base_layer.py 2441
# ----------------------------debug traceback_utils.py 101
# The caller function is '_infer_output_signature' in module 'keras.engine.base_layer' (current in base_layer.py 989)
# ----------------------------debug base_layer.py 2462
# ----------------------------debug base_layer.py 2471
# ----------------------------debug base_layer.py 983
# str(self.name): activation_4
# The caller function is 'error_handler' in module 'keras.utils.traceback_utils' (current in base_layer.py 989)
# args: (<KerasTensor: shape=(None, None, None, 64) dtype=float32 (created by layer 'bn2b_branch2b')>,)
# kwargs: {}
# ----------------------------debug base_layer.py 1009
# ----------------------------debug base_layer.py 1011
# ----------------------------debug base_layer.py 1013
# ----------------------------debug base_layer.py 1023
# The caller function is '_functional_construction_call' in module 'keras.engine.base_layer' (current in base_layer.py 2358)
# The caller function is '<listcomp>' in module 'tensorflow.python.util.nest' (currently in keras_tensor.py 670)
# ----------------------------debug keras_tensor.py 243
# The caller function is 'keras_tensor_to_placeholder' in module 'keras.engine.keras_tensor' (currently in keras_tensor.py 248)
# keras_tensor.py self: KerasTensor(type_spec=TensorSpec(shape=(None, None, None, 64), dtype=tf.float32, name=None), name='bn2b_branch2b/FusedBatchNormV3:0', description="created by layer 'bn2b_branch2b'")
# component_to_placeholder: <function KerasTensor._to_placeholder.<locals>.component_to_placeholder at 0x000001CE3B61DD80>
# self.type_spec: TensorSpec(shape=(None, None, None, 64), dtype=tf.float32, name=None)
# ...
# outputs: Tensor("mrcnn_mask_conv4/conv2d_5/BiasAdd:0", shape=(100, 14, 14, 256), dtype=float32)
# ----------------------------debug base_layer.py 2462
# ----------------------------debug base_layer.py 2471
# ----------------------------debug base_layer.py 983
# str(self.name): mrcnn_mask_bn4
# The caller function is 'error_handler' in module 'keras.utils.traceback_utils' (current in base_layer.py 989)
# args: (<KerasTensor: shape=(1, 100, 14, 14, 256) dtype=float32 (created by layer 'mrcnn_mask_conv4')>,)
# kwargs: {'training': False}
# ----------------------------debug base_layer.py 1009
# ----------------------------debug base_layer.py 1011
# ----------------------------debug base_layer.py 1013
# ----------------------------debug base_layer.py 1023
# The caller function is '_functional_construction_call' in module 'keras.engine.base_layer' (current in base_layer.py 2358)
# The caller function is '<listcomp>' in module 'tensorflow.python.util.nest' (currently in keras_tensor.py 670)
# ----------------------------debug keras_tensor.py 243
# The caller function is 'keras_tensor_to_placeholder' in module 'keras.engine.keras_tensor' (currently in keras_tensor.py 248)
# keras_tensor.py self: KerasTensor(type_spec=TensorSpec(shape=(1, 100, 14, 14, 256), dtype=tf.float32, name=None), name='mrcnn_mask_conv4/Reshape_1:0', description="created by layer 'mrcnn_mask_conv4'")
# component_to_placeholder: <function KerasTensor._to_placeholder.<locals>.component_to_placeholder at 0x000001CE3B609B40>
# self.type_spec: TensorSpec(shape=(1, 100, 14, 14, 256), dtype=tf.float32, name=None)
# The caller function is '<listcomp>' in module 'tensorflow.python.util.nest' (current in keras.engine.keras_tensor 238)
# The caller function is 'placeholder' in module 'tensorflow.python.ops.array_ops' (current in gen_array_ops.py 6902)
# name: None
# dtype: 1
# The caller function is '<listcomp>' in module 'tensorflow.python.util.nest' (currently in keras_tensor.py 670)
# The caller function is '<listcomp>' in module 'tensorflow.python.util.nest' (currently in keras_tensor.py 670)
# ----------------------------debug base_layer.py 2441
# ----------------------------debug traceback_utils.py 101
# The caller function is '_infer_output_signature' in module 'keras.engine.base_layer' (current in base_layer.py 989)
# ----------------------------debug base_layer.py 983
# str(self.name): batch_norm_5
# The caller function is 'error_handler' in module 'keras.utils.traceback_utils' (current in base_layer.py 989)
# args: (<tf.Tensor 'mrcnn_mask_bn4/Reshape:0' shape=(100, 14, 14, 256) dtype=float32>,)
# kwargs: {'training': False}
# ----------------------------debug base_layer.py 1009
# ----------------------------debug base_layer.py 1011
# ----------------------------debug base_layer.py 1013
# ----------------------------debug base_layer.py 1048
# ----------------------------debug base_layer.py 1112
# inputs: Tensor("mrcnn_mask_bn4/Reshape:0", shape=(100, 14, 14, 256), dtype=float32)
# ----------------------------debug traceback_utils.py 101
# The caller function is '__call__' in module 'keras.engine.base_layer' (current in base_layer.py 989)
# outputs: Tensor("mrcnn_mask_bn4/batch_norm_5/FusedBatchNormV3:0", shape=(100, 14, 14, 256), dtype=float32)
# ----------------------------debug base_layer.py 2462
# ----------------------------debug base_layer.py 2471
# ----------------------------debug base_layer.py 983
# str(self.name): activation_73
# The caller function is 'error_handler' in module 'keras.utils.traceback_utils' (current in base_layer.py 989)
# args: (<KerasTensor: shape=(1, 100, 14, 14, 256) dtype=float32 (created by layer 'mrcnn_mask_bn4')>,)
# kwargs: {}
# ----------------------------debug base_layer.py 1009
# ----------------------------debug base_layer.py 1011
# ----------------------------debug base_layer.py 1013
# ----------------------------debug base_layer.py 1023
# The caller function is '_functional_construction_call' in module 'keras.engine.base_layer' (current in base_layer.py 2358)
# The caller function is '<listcomp>' in module 'tensorflow.python.util.nest' (currently in keras_tensor.py 670)
# ----------------------------debug keras_tensor.py 243
# The caller function is 'keras_tensor_to_placeholder' in module 'keras.engine.keras_tensor' (currently in keras_tensor.py 248)
# keras_tensor.py self: KerasTensor(type_spec=TensorSpec(shape=(1, 100, 14, 14, 256), dtype=tf.float32, name=None), name='mrcnn_mask_bn4/Reshape_1:0', description="created by layer 'mrcnn_mask_bn4'")
# component_to_placeholder: <function KerasTensor._to_placeholder.<locals>.component_to_placeholder at 0x000001CE3B60A830>
# self.type_spec: TensorSpec(shape=(1, 100, 14, 14, 256), dtype=tf.float32, name=None)
# The caller function is '<listcomp>' in module 'tensorflow.python.util.nest' (current in keras.engine.keras_tensor 238)
# The caller function is 'placeholder' in module 'tensorflow.python.ops.array_ops' (current in gen_array_ops.py 6902)
# name: None
# dtype: 1
# The caller function is '<listcomp>' in module 'tensorflow.python.util.nest' (currently in keras_tensor.py 670)
# ----------------------------debug base_layer.py 2441
# ----------------------------debug traceback_utils.py 101
# The caller function is '_infer_output_signature' in module 'keras.engine.base_layer' (current in base_layer.py 989)
# ----------------------------debug base_layer.py 2462
# ----------------------------debug base_layer.py 2471
# ----------------------------debug base_layer.py 983
# str(self.name): mrcnn_mask_deconv
# The caller function is 'error_handler' in module 'keras.utils.traceback_utils' (current in base_layer.py 989)
# args: (<KerasTensor: shape=(1, 100, 14, 14, 256) dtype=float32 (created by layer 'activation_73')>,)
# kwargs: {}
# ----------------------------debug base_layer.py 1009
# ----------------------------debug base_layer.py 1011
# ----------------------------debug base_layer.py 1013
# ----------------------------debug base_layer.py 1023
# The caller function is '_functional_construction_call' in module 'keras.engine.base_layer' (current in base_layer.py 2358)
# The caller function is '<listcomp>' in module 'tensorflow.python.util.nest' (currently in keras_tensor.py 670)
# ----------------------------debug keras_tensor.py 243
# The caller function is 'keras_tensor_to_placeholder' in module 'keras.engine.keras_tensor' (currently in keras_tensor.py 248)
# keras_tensor.py self: KerasTensor(type_spec=TensorSpec(shape=(1, 100, 14, 14, 256), dtype=tf.float32, name=None), name='activation_73/Relu:0', description="created by layer 'activation_73'")
# component_to_placeholder: <function KerasTensor._to_placeholder.<locals>.component_to_placeholder at 0x000001CE3B6081F0>
# self.type_spec: TensorSpec(shape=(1, 100, 14, 14, 256), dtype=tf.float32, name=None)
# The caller function is '<listcomp>' in module 'tensorflow.python.util.nest' (current in keras.engine.keras_tensor 238)
# The caller function is 'placeholder' in module 'tensorflow.python.ops.array_ops' (current in gen_array_ops.py 6902)
# name: None
# dtype: 1
# The caller function is '<listcomp>' in module 'tensorflow.python.util.nest' (currently in keras_tensor.py 670)
# The caller function is '<listcomp>' in module 'tensorflow.python.util.nest' (currently in keras_tensor.py 670)
# ----------------------------debug base_layer.py 2441
# ----------------------------debug traceback_utils.py 101
# The caller function is '_infer_output_signature' in module 'keras.engine.base_layer' (current in base_layer.py 989)
# ----------------------------debug base_layer.py 983
# str(self.name): conv2d_transpose
# The caller function is 'error_handler' in module 'keras.utils.traceback_utils' (current in base_layer.py 989)
# args: (<tf.Tensor 'mrcnn_mask_deconv/Reshape:0' shape=(100, 14, 14, 256) dtype=float32>,)
# kwargs: {}
# ----------------------------debug base_layer.py 1009
# ----------------------------debug base_layer.py 1011
# ----------------------------debug base_layer.py 1013
# ----------------------------debug base_layer.py 1048
# ----------------------------debug base_layer.py 1112
# inputs: Tensor("mrcnn_mask_deconv/Reshape:0", shape=(100, 14, 14, 256), dtype=float32)
# ----------------------------debug traceback_utils.py 101
# The caller function is '__call__' in module 'keras.engine.base_layer' (current in base_layer.py 989)
# outputs: Tensor("mrcnn_mask_deconv/conv2d_transpose/Relu:0", shape=(100, 28, 28, 256), dtype=float32)
# ----------------------------debug base_layer.py 2462
# ----------------------------debug base_layer.py 2471
# ----------------------------debug base_layer.py 983
# str(self.name): mrcnn_mask
# The caller function is 'error_handler' in module 'keras.utils.traceback_utils' (current in base_layer.py 989)
# args: (<KerasTensor: shape=(1, 100, 28, 28, 256) dtype=float32 (created by layer 'mrcnn_mask_deconv')>,)
# kwargs: {}
# ----------------------------debug base_layer.py 1009
# ----------------------------debug base_layer.py 1011
# ----------------------------debug base_layer.py 1013
# ----------------------------debug base_layer.py 1023
# The caller function is '_functional_construction_call' in module 'keras.engine.base_layer' (current in base_layer.py 2358)
# The caller function is '<listcomp>' in module 'tensorflow.python.util.nest' (currently in keras_tensor.py 670)
# ----------------------------debug keras_tensor.py 243
# The caller function is 'keras_tensor_to_placeholder' in module 'keras.engine.keras_tensor' (currently in keras_tensor.py 248)
# keras_tensor.py self: KerasTensor(type_spec=TensorSpec(shape=(1, 100, 28, 28, 256), dtype=tf.float32, name=None), name='mrcnn_mask_deconv/Reshape_1:0', description="created by layer 'mrcnn_mask_deconv'")
# component_to_placeholder: <function KerasTensor._to_placeholder.<locals>.component_to_placeholder at 0x000001CE3B608820>
# self.type_spec: TensorSpec(shape=(1, 100, 28, 28, 256), dtype=tf.float32, name=None)
# The caller function is '<listcomp>' in module 'tensorflow.python.util.nest' (current in keras.engine.keras_tensor 238)
# The caller function is 'placeholder' in module 'tensorflow.python.ops.array_ops' (current in gen_array_ops.py 6902)
# name: None
# dtype: 1
# The caller function is '<listcomp>' in module 'tensorflow.python.util.nest' (currently in keras_tensor.py 670)
# The caller function is '<listcomp>' in module 'tensorflow.python.util.nest' (currently in keras_tensor.py 670)
# ----------------------------debug base_layer.py 2441
# ----------------------------debug traceback_utils.py 101
# The caller function is '_infer_output_signature' in module 'keras.engine.base_layer' (current in base_layer.py 989)
# ----------------------------debug base_layer.py 983
# str(self.name): conv2d_6
# The caller function is 'error_handler' in module 'keras.utils.traceback_utils' (current in base_layer.py 989)
# args: (<tf.Tensor 'mrcnn_mask/Reshape:0' shape=(100, 28, 28, 256) dtype=float32>,)
# kwargs: {}
# ----------------------------debug base_layer.py 1009
# ----------------------------debug base_layer.py 1011
# ----------------------------debug base_layer.py 1013
# ----------------------------debug base_layer.py 1048
# ----------------------------debug base_layer.py 1112
# inputs: Tensor("mrcnn_mask/Reshape:0", shape=(100, 28, 28, 256), dtype=float32)
# ----------------------------debug traceback_utils.py 101
# The caller function is '__call__' in module 'keras.engine.base_layer' (current in base_layer.py 989)
# outputs: Tensor("mrcnn_mask/conv2d_6/Sigmoid:0", shape=(100, 28, 28, 81), dtype=float32)
# ----------------------------debug base_layer.py 2462
# ----------------------------debug base_layer.py 2471
# ----------------------------debug functional.py 1102
# inputs: [<KerasTensor: shape=(None, None, None, 3) dtype=float32 (created by layer 'input_image')>, <KerasTensor: shape=(None, 93) dtype=float32 (created by layer 'input_image_meta')>, <KerasTensor: shape=(None, None, 4) dtype=float32 (created by layer 'input_anchors')>]
# The caller function is '_init_graph_network' in module 'keras.engine.functional' (current in functional.py 1108)
# ----------------------------debug functional.py 1159
# len nodes_by_depth: 374
# layers_with_complete_input: ['zero_padding2d', 'conv1', 'bn_conv1', 'activation', 'max_pooling2d', 'res2a_branch2a', 'bn2a_branch2a', 'activation_1', 'res2a_branch2b', 'bn2a_branch2b', 'activation_2', 'res2a_branch1', 'res2a_branch2c', 'bn2a_branch2c', 'bn2a_branch1', 'add', 'res2a_out', 'res2b_branch2a', 'bn2b_branch2a', 'activation_3', 'res2b_branch2b', 'bn2b_branch2b', 'activation_4', 'res2b_branch2c', 'bn2b_branch2c', 'add_1', 'res2b_out', 'res2c_branch2a', 'bn2c_branch2a', 'activation_5', 'res2c_branch2b', 'bn2c_branch2b', 'activation_6', 'res2c_branch2c', 'bn2c_branch2c', 'add_2', 'res2c_out', 'res3a_branch2a', 'bn3a_branch2a', 'activation_7', 'res3a_branch2b', 'bn3a_branch2b', 'activation_8', 'res3a_branch1', 'res3a_branch2c', 'bn3a_branch2c', 'bn3a_branch1', 'add_3', 'res3a_out', 'res3b_branch2a', 'bn3b_branch2a', 'activation_9', 'res3b_branch2b', 'bn3b_branch2b', 'activation_10', 'res3b_branch2c', 'bn3b_branch2c', 'add_4', 'res3b_out', 'res3c_branch2a', 'bn3c_branch2a', 'activation_11', 'res3c_branch2b', 'bn3c_branch2b', 'activation_12', 'res3c_branch2c', 'bn3c_branch2c', 'add_5', 'res3c_out', 'res3d_branch2a', 'bn3d_branch2a', 'activation_13', 'res3d_branch2b', 'bn3d_branch2b', 'activation_14', 'res3d_branch2c', 'bn3d_branch2c', 'add_6', 'res3d_out', 'res4a_branch2a', 'bn4a_branch2a', 'activation_15', 'res4a_branch2b', 'bn4a_branch2b', 'activation_16', 'res4a_branch1', 'res4a_branch2c', 'bn4a_branch2c', 'bn4a_branch1', 'add_7', 'res4a_out', 'res4b_branch2a', 'bn4b_branch2a', 'activation_17', 'res4b_branch2b', 'bn4b_branch2b', 'activation_18', 'res4b_branch2c', 'bn4b_branch2c', 'add_8', 'res4b_out', 'res4c_branch2a', 'bn4c_branch2a', 'activation_19', 'res4c_branch2b', 'bn4c_branch2b', 'activation_20', 'res4c_branch2c', 'bn4c_branch2c', 'add_9', 'res4c_out', 'res4d_branch2a', 'bn4d_branch2a', 'activation_21', 'res4d_branch2b', 'bn4d_branch2b', 'activation_22', 'res4d_branch2c', 'bn4d_branch2c', 'add_10', 'res4d_out', 'res4e_branch2a', 'bn4e_branch2a', 'activation_23', 'res4e_branch2b', 'bn4e_branch2b', 'activation_24', 'res4e_branch2c', 'bn4e_branch2c', 'add_11', 'res4e_out', 'res4f_branch2a', 'bn4f_branch2a', 'activation_25', 'res4f_branch2b', 'bn4f_branch2b', 'activation_26', 'res4f_branch2c', 'bn4f_branch2c', 'add_12', 'res4f_out', 'res4g_branch2a', 'bn4g_branch2a', 'activation_27', 'res4g_branch2b', 'bn4g_branch2b', 'activation_28', 'res4g_branch2c', 'bn4g_branch2c', 'add_13', 'res4g_out', 'res4h_branch2a', 'bn4h_branch2a', 'activation_29', 'res4h_branch2b', 'bn4h_branch2b', 'activation_30', 'res4h_branch2c', 'bn4h_branch2c', 'add_14', 'res4h_out', 'res4i_branch2a', 'bn4i_branch2a', 'activation_31', 'res4i_branch2b', 'bn4i_branch2b', 'activation_32', 'res4i_branch2c', 'bn4i_branch2c', 'add_15', 'res4i_out', 'res4j_branch2a', 'bn4j_branch2a', 'activation_33', 'res4j_branch2b', 'bn4j_branch2b', 'activation_34', 'res4j_branch2c', 'bn4j_branch2c', 'add_16', 'res4j_out', 'res4k_branch2a', 'bn4k_branch2a', 'activation_35', 'res4k_branch2b', 'bn4k_branch2b', 'activation_36', 'res4k_branch2c', 'bn4k_branch2c', 'add_17', 'res4k_out', 'res4l_branch2a', 'bn4l_branch2a', 'activation_37', 'res4l_branch2b', 'bn4l_branch2b', 'activation_38', 'res4l_branch2c', 'bn4l_branch2c', 'add_18', 'res4l_out', 'res4m_branch2a', 'bn4m_branch2a', 'activation_39', 'res4m_branch2b', 'bn4m_branch2b', 'activation_40', 'res4m_branch2c', 'bn4m_branch2c', 'add_19', 'res4m_out', 'res4n_branch2a', 'bn4n_branch2a', 'activation_41', 'res4n_branch2b', 'bn4n_branch2b', 'activation_42', 'res4n_branch2c', 'bn4n_branch2c', 'add_20', 'res4n_out', 'res4o_branch2a', 'bn4o_branch2a', 'activation_43', 'res4o_branch2b', 'bn4o_branch2b', 'activation_44', 'res4o_branch2c', 'bn4o_branch2c', 'add_21', 'res4o_out', 'res4p_branch2a', 'bn4p_branch2a', 'activation_45', 'res4p_branch2b', 'bn4p_branch2b', 'activation_46', 'res4p_branch2c', 'bn4p_branch2c', 'add_22', 'res4p_out', 'res4q_branch2a', 'bn4q_branch2a', 'activation_47', 'res4q_branch2b', 'bn4q_branch2b', 'activatio ...
# ---------------------debug model built

# %%
# COCO Class names
# Index of the class in the list is its ID. For example, to get ID of
# the teddy bear class, use: class_names.index('teddy bear')
class_names = ['BG', 'person', 'bicycle', 'car', 'motorcycle', 'airplane',
               'bus', 'train', 'truck', 'boat', 'traffic light',
               'fire hydrant', 'stop sign', 'parking meter', 'bench', 'bird',
               'cat', 'dog', 'horse', 'sheep', 'cow', 'elephant', 'bear',
               'zebra', 'giraffe', 'backpack', 'umbrella', 'handbag', 'tie',
               'suitcase', 'frisbee', 'skis', 'snowboard', 'sports ball',
               'kite', 'baseball bat', 'baseball glove', 'skateboard',
               'surfboard', 'tennis racket', 'bottle', 'wine glass', 'cup',
               'fork', 'knife', 'spoon', 'bowl', 'banana', 'apple',
               'sandwich', 'orange', 'broccoli', 'carrot', 'hot dog', 'pizza',
               'donut', 'cake', 'chair', 'couch', 'potted plant', 'bed',
               'dining table', 'toilet', 'tv', 'laptop', 'mouse', 'remote',
               'keyboard', 'cell phone', 'microwave', 'oven', 'toaster',
               'sink', 'refrigerator', 'book', 'clock', 'vase', 'scissors',
               'teddy bear', 'hair drier', 'toothbrush']

# %%
# Directory of images to run detection on
IMAGE_DIR = os.path.join(ROOT_DIR, 'Mask_RCNN\\images\\mrcnn_target')
file_names = next(os.walk(IMAGE_DIR))[2]
for file_name in file_names:
    image = skimage.io.imread(os.path.join(IMAGE_DIR, file_name))

    # Run detection
    results = model.detect([image], verbose=1)

    # Visualize results
    r = results[0]
    visualize.save_instances_augmentation(image, r['rois'], r['masks'], r['class_ids'], 
                                class_names, scores=r['scores'], augmentation_file_name=file_name)
# Out:
# Processing 1 images
# image                    shape: (800, 1280, 3)        min:    0.00000  max:  255.00000  uint8
# molded_images            shape: (1, 1024, 1024, 3)    min: -123.70000  max:  151.10000  float64
# image_metas              shape: (1, 93)               min:    0.00000  max: 1280.00000  float64
# anchors                  shape: (1, 261888, 4)        min:   -0.35390  max:    1.29134  float32
# ----------------------------debug function.py 2654
# The caller function is '_maybe_define_function' in module 'tensorflow.python.eager.function'
# ----------------------------debug func_graph.py 1187
# The caller function is '_create_graph_function' in module 'tensorflow.python.eager.function'
# ----------------------------debug function.py 2654
# The caller function is '_maybe_define_function' in module 'tensorflow.python.eager.function'
# ----------------------------debug func_graph.py 1187
# The caller function is '_create_graph_function' in module 'tensorflow.python.eager.function'
# ----------------------------debug function.py 2654
# The caller function is '_maybe_define_function' in module 'tensorflow.python.eager.function'
# ----------------------------debug func_graph.py 1187
# The caller function is '_create_graph_function' in module 'tensorflow.python.eager.function'
# ----------------------------debug def_function.py 755
# The caller function is '_call' in module 'tensorflow.python.eager.def_function'
# ----------------------------debug function.py 2520
# The caller function is '_initialize' in module 'tensorflow.python.eager.def_function'
# ----------------------------debug function.py 2654
# The caller function is '_maybe_define_function' in module 'tensorflow.python.eager.function'
# ----------------------------debug func_graph.py 1187
# The caller function is '_create_graph_function' in module 'tensorflow.python.eager.function'
# ----------------------------debug def_function.py 672
# The caller function is 'func_graph_from_py_func' in module 'tensorflow.python.framework.func_graph'
# ----------------------------debug func_graph.py 1267
# The caller function is 'wrapped_fn' in module 'tensorflow.python.eager.def_function'
# ----------------------------debug base_layer.py 983
# str(self.name): mask_rcnn
# The caller function is 'error_handler' in module 'keras.utils.traceback_utils' (current in base_layer.py 989)
# args: ((<tf.Tensor 'IteratorGetNext:0' shape=(None, 1024, 1024, 3) dtype=float32>, <tf.Tensor 'IteratorGetNext:1' shape=(None, 93) dtype=float32>, <tf.Tensor 'IteratorGetNext:2' shape=(None, 261888, 4) dtype=float32>),)
# kwargs: {'training': False}
# ----------------------------debug base_layer.py 1009
# ----------------------------debug base_layer.py 1011
# ----------------------------debug base_layer.py 1013
# ----------------------------debug base_layer.py 1048
# ----------------------------debug base_layer.py 1112
# inputs: (<tf.Tensor 'IteratorGetNext:0' shape=(None, 1024, 1024, 3) dtype=float32>, <tf.Tensor 'IteratorGetNext:1' shape=(None, 93) dtype=float32>, <tf.Tensor 'IteratorGetNext:2' shape=(None, 261888, 4) dtype=float32>)
# ----------------------------debug traceback_utils.py 101
# The caller function is '__call__' in module 'keras.engine.base_layer' (current in base_layer.py 989)
# ----------------------------debug base_layer.py 983
# str(self.name): zero_padding2d
# The caller function is 'error_handler' in module 'keras.utils.traceback_utils' (current in base_layer.py 989)
# args: (<tf.Tensor 'IteratorGetNext:0' shape=(None, 1024, 1024, 3) dtype=float32>,)
# kwargs: {}
# ----------------------------debug base_layer.py 1009
# ----------------------------debug base_layer.py 1011
# ----------------------------debug base_layer.py 1013
# ----------------------------debug base_layer.py 1048
# ----------------------------debug base_layer.py 1112
# inputs: Tensor("IteratorGetNext:0", shape=(None, 1024, 1024, 3), dtype=float32)
# ----------------------------debug traceback_utils.py 101
# The caller function is '__call__' in module 'keras.engine.base_layer' (current in base_layer.py 989)
# outputs: Tensor("mask_rcnn/zero_padding2d/Pad:0", shape=(None, 1030, 1030, 3), dtype=float32)
# ----------------------------debug base_layer.py 983
# str(self.name): conv1
# The caller function is 'error_handler' in module 'keras.utils.traceback_utils' (current in base_layer.py 989)
# args: (<tf.Tensor 'mask_rcnn/zero_padding2d/Pad:0' shape=(None, 1030, 1030, 3) dtype=float32>,)
# kwargs: {}
# ----------------------------debug base_layer.py 1009
# ----------------------------debug base_layer.py 1011
# ----------------------------debug base_layer.py 1013
# ----------------------------debug base_layer.py 1048
# ----------------------------debug base_layer.py 1112
# inputs: Tensor("mask_rcnn/zero_padding2d/Pad:0", shape=(None, 1030, 1030, 3), dtype=float32)
# ----------------------------debug traceback_utils.py 101
# The caller function is '__call__' in module 'keras.engine.base_layer' (current in base_layer.py 989)
# outputs: Tensor("mask_rcnn/conv1/BiasAdd:0", shape=(None, 512, 512, 64), dtype=float32)
# ----------------------------debug base_layer.py 983
# str(self.name): bn_conv1
# The caller function is 'error_handler' in module 'keras.utils.traceback_utils' (current in base_layer.py 989)
# args: (<tf.Tensor 'mask_rcnn/conv1/BiasAdd:0' shape=(None, 512, 512, 64) dtype=float32>,)
# kwargs: {'training': False}
# ----------------------------debug base_layer.py 1009
# ----------------------------debug base_layer.py 1011
# ----------------------------debug base_layer.py 1013
# ----------------------------debug base_layer.py 1048
# ----------------------------debug base_layer.py 1112
# inputs: Tensor("mask_rcnn/conv1/BiasAdd:0", shape=(None, 512, 512, 64), dtype=float32)
# ----------------------------debug traceback_utils.py 101
# The caller function is '__call__' in module 'keras.engine.base_layer' (current in base_layer.py 989)
# outputs: Tensor("mask_rcnn/bn_conv1/FusedBatchNormV3:0", shape=(None, 512, 512, 64), dtype=float32)
# ----------------------------debug base_layer.py 983
# str(self.name): activation
# The caller function is 'error_handler' in module 'keras.utils.traceback_utils' (current in base_layer.py 989)
# args: (<tf.Tensor 'mask_rcnn/bn_conv1/FusedBatchNormV3:0' shape=(None, 512, 512, 64) dtype=float32>,)
# kwargs: {}
# ----------------------------debug base_layer.py 1009
# ----------------------------debug base_layer.py 1011
# ----------------------------debug base_layer.py 1013
# ----------------------------debug base_layer.py 1048
# ----------------------------debug base_layer.py 1112
# inputs: Tensor("mask_rcnn/bn_conv1/FusedBatchNormV3:0", shape=(None, 512, 512, 64), dtype=float32)
# ----------------------------debug traceback_utils.py 101
# The caller function is '__call__' in module 'keras.engine.base_layer' (current in base_layer.py 989)
# outputs: Tensor("mask_rcnn/activation/Relu:0", shape=(None, 512, 512, 64), dtype=float32)
# ----------------------------debug base_layer.py 983
# str(self.name): max_pooling2d
# The caller function is 'error_handler' in module 'keras.utils.traceback_utils' (current in base_layer.py 989)
# args: (<tf.Tensor 'mask_rcnn/activation/Relu:0' shape=(None, 512, 512, 64) dtype=float32>,)
# kwargs: {}
# ----------------------------debug base_layer.py 1009
# ----------------------------debug base_layer.py 1011
# ----------------------------debug base_layer.py 1013
# ----------------------------debug base_layer.py 1048
# ----------------------------debug base_layer.py 1112
# inputs: Tensor("mask_rcnn/activation/Relu:0", shape=(None, 512, 512, 64), dtype=float32)
# ----------------------------debug traceback_utils.py 101
# The caller function is '__call__' in module 'keras.engine.base_layer' (current in base_layer.py 989)
# outputs: Tensor("mask_rcnn/max_pooling2d/MaxPool:0", shape=(None, 256, 256, 64), dtype=float32)
# ----------------------------debug base_layer.py 983
# str(self.name): res2a_branch2a
# The caller function is 'error_handler' in module 'keras.utils.traceback_utils' (current in base_layer.py 989)
# args: (<tf.Tensor 'mask_rcnn/max_pooling2d/MaxPool:0' shape=(None, 256, 256, 64) dtype=float32>,)
# kwargs: {}
# ----------------------------debug base_layer.py 1009
# ----------------------------debug base_layer.py 1011
# ----------------------------debug base_layer.py 1013
# ----------------------------debug base_layer.py 1048
# ----------------------------debug base_layer.py 1112
# inputs: Tensor("mask_rcnn/max_pooling2d/MaxPool:0", shape=(None, 256, 256, 64), dtype=float32)
# ----------------------------debug traceback_utils.py 101
# The caller function is '__call__' in module 'keras.engine.base_layer' (current in base_layer.py 989)
# outputs: Tensor("mask_rcnn/res2a_branch2a/BiasAdd:0", shape=(None, 256, 256, 64), dtype=float32)
# ----------------------------debug base_layer.py 983
# str(self.name): bn2a_branch2a
# The caller function is 'error_handler' in module 'keras.utils.traceback_utils' (current in base_layer.py 989)
# args: (<tf.Tensor 'mask_rcnn/res2a_branch2a/BiasAdd:0' shape=(None, 256, 256, 64) dtype=float32>,)
# kwargs: {'training': False}
# ----------------------------debug base_layer.py 1009
# ----------------------------debug base_layer.py 1011
# ----------------------------debug base_layer.py 1013
# ----------------------------debug base_layer.py 1048
# ----------------------------debug base_layer.py 1112
# inputs: Tensor("mask_rcnn/res2a_branch2a/BiasAdd:0", shape=(None, 256, 256, 64), dtype=float32)
# ----------------------------debug traceback_utils.py 101
# The caller function is '__call__' in module 'keras.engine.base_layer' (current in base_layer.py 989)
# outputs: Tensor("mask_rcnn/bn2a_branch2a/FusedBatchNormV3:0", shape=(None, 256, 256, 64), dtype=float32)
# ----------------------------debug base_layer.py 983
# str(self.name): activation_1
# The caller function is 'error_handler' in module 'keras.utils.traceback_utils' (current in base_layer.py 989)
# args: (<tf.Tensor 'mask_rcnn/bn2a_branch2a/FusedBatchNormV3:0' shape=(None, 256, 256, 64) dtype=float32>,)
# kwargs: {}
# ----------------------------debug base_layer.py 1009
# ----------------------------debug base_layer.py 1011
# ----------------------------debug base_layer.py 1013
# ----------------------------debug base_layer.py 1048
# ----------------------------debug base_layer.py 1112
# inputs: Tensor("mask_rcnn/bn2a_branch2a/FusedBatchNormV3:0", shape=(None, 256, 256, 64), dtype=float32)
# ----------------------------debug traceback_utils.py 101
# The caller function is '__call__' in module 'keras.engine.base_layer' (current in base_layer.py 989)
# outputs: Tensor("mask_rcnn/activation_1/Relu:0", shape=(None, 256, 256, 64), dtype=float32)
# ----------------------------debug base_layer.py 983
# str(self.name): res2a_branch2b
# The caller function is 'error_handler' in module 'keras.utils.traceback_utils' (current in base_layer.py 989)
# args: (<tf.Tensor 'mask_rcnn/activation_1/Relu:0' shape=(None, 256, 256, 64) dtype=float32>,)
# kwargs: {}
# ----------------------------debug base_layer.py 1009
# ----------------------------debug base_layer.py 1011
# ----------------------------debug base_layer.py 1013
# ----------------------------debug base_layer.py 1048
# ----------------------------debug base_layer.py 1112
# inputs: Tensor("mask_rcnn/activation_1/Relu:0", shape=(None, 256, 256, 64), dtype=float32)
# ----------------------------debug traceback_utils.py 101
# The caller function is '__call__' in module 'keras.engine.base_layer' (current in base_layer.py 989)
# outputs: Tensor("mask_rcnn/res2a_branch2b/BiasAdd:0", shape=(None, 256, 256, 64), dtype=float32)
# ----------------------------debug base_layer.py 983
# str(self.name): bn2a_branch2b
# The caller function is 'error_handler' in module 'keras.utils.traceback_utils' (current in base_layer.py 989)
# args: (<tf.Tensor 'mask_rcnn/res2a_branch2b/BiasAdd:0' shape=(None, 256, 256, 64) dtype=float32>,)
# kwargs: {'training': False}
# ----------------------------debug base_layer.py 1009
# ----------------------------debug base_layer.py 1011
# ----------------------------debug base_layer.py 1013
# ----------------------------debug base_layer.py 1048
# ----------------------------debug base_layer.py 1112
# inputs: Tensor("mask_rcnn/res2a_branch2b/BiasAdd:0", shape=(None, 256, 256, 64), dtype=float32)
# ----------------------------debug traceback_utils.py 101
# The caller function is '__call__' in module 'keras.engine.base_layer' (current in base_layer.py 989)
# outputs: Tensor("mask_rcnn/bn2a_branch2b/FusedBatchNormV3:0", shape=(None, 256, 256, 64), dtype=float32)
# ----------------------------debug base_layer.py 983
# str(self.name): activation_2
# The caller function is 'error_handler' in module 'keras.utils.traceback_utils' (current in base_layer.py 989)
# args: (<tf.Tensor 'mask_rcnn/bn2a_branch2b/FusedBatchNormV3:0' shape=(None, 256, 256, 64) dtype=float32>,)
# kwargs: {}
# ----------------------------debug base_layer.py 1009
# ----------------------------debug base_layer.py 1011
# ----------------------------debug base_layer.py 1013
# ----------------------------debug base_layer.py 1048
# ----------------------------debug base_layer.py 1112
# inputs: Tensor("mask_rcnn/bn2a_branch2b/FusedBatchNormV3:0", shape=(None, 256, 256, 64), dtype=float32)
# ----------------------------debug traceback_utils.py 101
# The caller function is '__call__' in module 'keras.engine.base_layer' (current in base_layer.py 989)
# outputs: Tensor("mask_rcnn/activation_2/Relu:0", shape=(None, 256, 256, 64), dtype=float32)
# ----------------------------debug base_layer.py 983
# str(self.name): res2a_branch1
# The caller function is 'error_handler' in module 'keras.utils.traceback_utils' (current in base_layer.py 989)
# args: (<tf.Tensor 'mask_rcnn/max_pooling2d/MaxPool:0' shape=(None, 256, 256, 64) dtype=float32>,)
# kwargs: {}
# ----------------------------debug base_layer.py 1009
# ----------------------------debug base_layer.py 1011
# ----------------------------debug base_layer.py 1013
# ----------------------------debug base_layer.py 1048
# ----------------------------debug base_layer.py 1112
# inputs: Tensor("mask_rcnn/max_pooling2d/MaxPool:0", shape=(None, 256, 256, 64), dtype=float32)
# ----------------------------debug traceback_utils.py 101
# The caller function is '__call__' in module 'keras.engine.base_layer' (current in base_layer.py 989)
# outputs: Tensor("mask_rcnn/res2a_branch1/BiasAdd:0", shape=(None, 256, 256, 256), dtype=float32)
# ----------------------------debug base_layer.py 983
# str(self.name): res2a_branch2c
# The caller function is 'error_handler' in module 'keras.utils.traceback_utils' (current in base_layer.py 989)
# args: (<tf.Tensor 'mask_rcnn/activation_2/Relu:0' shape=(None, 256, 256, 64) dtype=float32>,)
# kwargs: {}
# ----------------------------debug base_layer.py 1009
# ----------------------------debug base_layer.py 1011
# ----------------------------debug base_layer.py 1013
# ----------------------------debug base_layer.py 1048
# ----------------------------debug base_layer.py 1112
# inputs: Tensor("mask_rcnn/activation_2/Relu:0", shape=(None, 256, 256, 64), dtype=float32)
# ----------------------------debug traceback_utils.py 101
# The caller function is '__call__' in module 'keras.engine.base_layer' (current in base_layer.py 989)
# outputs: Tensor("mask_rcnn/res2a_branch2c/BiasAdd:0", shape=(None, 256, 256, 256), dtype=float32)
# ----------------------------debug base_layer.py 983
# str(self.name): bn2a_branch2c
# The caller function is 'error_handler' in module 'keras.utils.traceback_utils' (current in base_layer.py 989)
# args: (<tf.Tensor 'mask_rcnn/res2a_branch2c/BiasAdd:0' shape=(None, 256, 256, 256) dtype=float32>,)
# kwargs: {'training': False}
# ----------------------------debug base_layer.py 1009
# ----------------------------debug base_layer.py 1011
# ----------------------------debug base_layer.py 1013
# ----------------------------debug base_layer.py 1048
# ----------------------------debug base_layer.py 1112
# inputs: Tensor("mask_rcnn/res2a_branch2c/BiasAdd:0", shape=(None, 256, 256, 256), dtype=float32)
# ----------------------------debug traceback_utils.py 101
# The caller function is '__call__' in module 'keras.engine.base_layer' (current in base_layer.py 989)
# outputs: Tensor("mask_rcnn/bn2a_branch2c/FusedBatchNormV3:0", shape=(None, 256, 256, 256), dtype=float32)
# ----------------------------debug base_layer.py 983
# str(self.name): bn2a_branch1
# The caller function is 'error_handler' in module 'keras.utils.traceback_utils' (current in base_layer.py 989)
# args: (<tf.Tensor 'mask_rcnn/res2a_branch1/BiasAdd:0' shape=(None, 256, 256, 256) dtype=float32>,)
# kwargs: {'training': False}
# ----------------------------debug base_layer.py 1009
# ----------------------------debug base_layer.py 1011
# ----------------------------debug base_layer.py 1013
# ----------------------------debug base_layer.py 1048
# ----------------------------debug base_layer.py 1112
# inputs: Tensor("mask_rcnn/res2a_branch1/BiasAdd:0", shape=(None, 256, 256, 256), dtype=float32)
# ----------------------------debug traceback_utils.py 101
# The caller function is '__call__' in module 'keras.engine.base_layer' (current in base_layer.py 989)
# outputs: Tensor("mask_rcnn/bn2a_branch1/FusedBatchNormV3:0", shape=(None, 256, 256, 256), dtype=float32)
# ----------------------------debug base_layer.py 983
# str(self.name): add
# The caller function is 'error_handler' in module 'keras.utils.traceback_utils' (current in base_layer.py 989)
# args: ([<tf.Tensor 'mask_rcnn/bn2a_branch2c/FusedBatchNormV3:0' shape=(None, 256, 256, 256) dtype=float32>, <tf.Tensor 'mask_rcnn/bn2a_branch1/FusedBatchNormV3:0' shape=(None, 256, 256, 256) dtype=float32>],)
# kwargs: {}
# ----------------------------debug base_layer.py 1009
# ----------------------------debug base_layer.py 1011
# ----------------------------debug base_layer.py 1013
# ----------------------------debug base_layer.py 1048
# ----------------------------debug base_layer.py 1112
# inputs: [<tf.Tensor 'mask_rcnn/bn2a_branch2c/FusedBatchNormV3:0' shape=(None, 256, 256, 256) dtype=float32>, <tf.Tensor 'mask_rcnn/bn2a_branch1/FusedBatchNormV3:0' shape=(None, 256, 256, 256) dtype=float32>]
# ----------------------------debug traceback_utils.py 101
# The caller function is '__call__' in module 'keras.engine.base_layer' (current in base_layer.py 989)
# outputs: Tensor("mask_rcnn/add/add:0", shape=(None, 256, 256, 256), dtype=float32)
# ----------------------------debug base_layer.py 983
# str(self.name): res2a_out
# The caller function is 'error_handler' in module 'keras.utils.traceback_utils' (current in base_layer.py 989)
# args: (<tf.Tensor 'mask_rcnn/add/add:0' shape=(None, 256, 256, 256) dtype=float32>,)
# kwargs: {}
# ----------------------------debug base_layer.py 1009
# ----------------------------debug base_layer.py 1011
# ----------------------------debug base_layer.py 1013
# ----------------------------debug base_layer.py 1048
# ----------------------------debug base_layer.py 1112
# inputs: Tensor("mask_rcnn/add/add:0", shape=(None, 256, 256, 256), dtype=float32)
# ----------------------------debug traceback_utils.py 101
# The caller function is '__call__' in module 'keras.engine.base_layer' (current in base_layer.py 989)
# outputs: Tensor("mask_rcnn/res2a_out/Relu:0", shape=(None, 256, 256, 256), dtype=float32)
# ----------------------------debug base_layer.py 983
# str(self.name): res2b_branch2a
# The caller function is 'error_handler' in module 'keras.utils.traceback_utils' (current in base_layer.py 989)
# args: (<tf.Tensor 'mask_rcnn/res2a_out/Relu:0' shape=(None, 256, 256, 256) dtype=float32>,)
# kwargs: {}
# ----------------------------debug base_layer.py 1009
# ----------------------------debug base_layer.py 1011
# ----------------------------debug base_layer.py 1013
# ----------------------------debug base_layer.py 1048
# ----------------------------debug base_layer.py 1112
# inputs: Tensor("mask_rcnn/res2a_out/Relu:0", shape=(None, 256, 256, 256), dtype=float32)
# ----------------------------debug traceback_utils.py 101
# The caller function is '__call__' in module 'keras.engine.base_layer' (current in base_layer.py 989)
# outputs: Tensor("mask_rcnn/res2b_branch2a/BiasAdd:0", shape=(None, 256, 256, 64), dtype=float32)
# ----------------------------debug base_layer.py 983
# str(self.name): bn2b_branch2a
# The caller function is 'error_handler' in module 'keras.utils.traceback_utils' (current in base_layer.py 989)
# args: (<tf.Tensor 'mask_rcnn/res2b_branch2a/BiasAdd:0' shape=(None, 256, 256, 64) dtype=float32>,)
# kwargs: {'training': False}
# ----------------------------debug base_layer.py 1009
# ----------------------------debug base_layer.py 1011
# ----------------------------debug base_layer.py 1013
# ----------------------------debug base_layer.py 1048
# ----------------------------debug base_layer.py 1112
# inputs: Tensor("mask_rcnn/res2b_branch2a/BiasAdd:0", shape=(None, 256, 256, 64), dtype=float32)
# ----------------------------debug traceback_utils.py 101
# The caller function is '__call__' in module 'keras.engine.base_layer' (current in base_layer.py 989)
# outputs: Tensor("mask_rcnn/bn2b_branch2a/FusedBatchNormV3:0", shape=(None, 256, 256, 64), dtype=float32)
# ----------------------------debug base_layer.py 983
# str(self.name): activation_3
# The caller function is 'error_handler' in module 'keras.utils.traceback_utils' (current in base_layer.py 989)
# args: (<tf.Tensor 'mask_rcnn/bn2b_branch2a/FusedBatchNormV3:0' shape=(None, 256, 256, 64) dtype=float32>,)
# kwargs: {}
# ----------------------------debug base_layer.py 1009
# ----------------------------debug base_layer.py 1011
# ----------------------------debug base_layer.py 1013
# ----------------------------debug base_layer.py 1048
# ----------------------------debug base_layer.py 1112
# inputs: Tensor("mask_rcnn/bn2b_branch2a/FusedBatchNormV3:0", shape=(None, 256, 256, 64), dtype=float32)
# ----------------------------debug traceback_utils.py 101
# The caller function is '__call__' in module 'keras.engine.base_layer' (current in base_layer.py 989)
# outputs: Tensor("mask_rcnn/activation_3/Relu:0", shape=(None, 256, 256, 64), dtype=float32)
# ----------------------------debug base_layer.py 983
# str(self.name): res2b_branch2b
# The caller function is 'error_handler' in module 'keras.utils.traceback_utils' (current in base_layer.py 989)
# args: (<tf.Tensor 'mask_rcnn/activation_3/Relu:0' shape=(None, 256, 256, 64) dtype=float32>,)
# kwargs: {}
# ----------------------------debug base_layer.py 1009
# ----------------------------debug base_layer.py 1011
# ----------------------------debug base_layer.py 1013
# ----------------------------debug base_layer.py 1048
# ----------------------------debug base_layer.py 1112
# inputs: Tensor("mask_rcnn/activation_3/Relu:0", shape=(None, 256, 256, 64), dtype=float32)
# ----------------------------debug traceback_utils.py 101
# The caller function is '__call__' in module 'keras.engine.base_layer' (current in base_layer.py 989)
# outputs: Tensor("mask_rcnn/res2b_branch2b/BiasAdd:0", shape=(None, 256, 256, 64), dtype=float32)
# ----------------------------debug base_layer.py 983
# str(self.name): bn2b_branch2b
# The caller function is 'error_handler' in module 'keras.utils.traceback_utils' (current in base_layer.py 989)
# args: (<tf.Tensor 'mask_rcnn/res2b_branch2b/BiasAdd:0' shape=(None, 256, 256, 64) dtype=float32>,)
# kwargs: {'training': False}
# ----------------------------debug base_layer.py 1009
# ----------------------------debug base_layer.py 1011
# ----------------------------debug base_layer.py 1013
# ----------------------------debug base_layer.py 1048
# ----------------------------debug base_layer.py 1112
# inputs: Tensor("mask_rcnn/res2b_branch2b/BiasAdd:0", shape=(None, 256, 256, 64), dtype=float32)
# ----------------------------debug traceback_utils.py 101
# The caller function is '__call__' in module 'keras.engine.base_layer' (current in base_layer.py 989)
# outputs: Tensor("mask_rcnn/bn2b_branch2b/FusedBatchNormV3:0", shape=(None, 256, 256, 64), dtype=float32)
# ----------------------------debug base_layer.py 983
# str(self.name): activation_4
# The caller function is 'error_handler' in module 'keras.utils.traceback_utils' (current in base_layer.py 989)
# args: (<tf.Tensor 'mask_rcnn/bn2b_branch2b/FusedBatchNormV3:0' shape=(None, 256, 256, 64) dtype=float32>,)
# kwargs: {}
# ----------------------------debug base_layer.py 1009
# ----------------------------debug base_layer.py 1011
# ----------------------------debug base_layer.py 1013
# ----------------------------debug base_layer.py 1048
# ----------------------------debug base_layer.py 1112
# inputs: Tensor("mask_rcnn/bn2b_branch2b/FusedBatchNormV3:0", shape=(None, 256, 256, 64), dtype=float32)
# ----------------------------debug traceback_utils.py 101
# The caller function is '__call__' in module 'keras.engine.base_layer' (current in base_layer.py 989)
# outputs: Tensor("mask_rcnn/activation_4/Relu:0", shape=(None, 256, 256, 64), dtype=float32)
# ----------------------------debug base_layer.py 983
# str(self.name): res2b_branch2c
# The caller function is 'error_handler' in module 'keras.utils.traceback_utils' (current in base_layer.py 989)
# args: (<tf.Tensor 'mask_rcnn/activation_4/Relu:0' shape=(None, 256, 256, 64) dtype=float32>,)
# kwargs: {}
# ----------------------------debug base_layer.py 1009
# ----------------------------debug base_layer.py 1011
# ----------------------------debug base_layer.py 1013
# ----------------------------debug base_layer.py 1048
# ----------------------------debug base_layer.py 1112
# inputs: Tensor("mask_rcnn/activation_4/Relu:0", shape=(None, 256, 256, 64), dtype=float32)
# ----------------------------debug traceback_utils.py 101
# The caller function is '__call__' in module 'keras.engine.base_layer' (current in base_layer.py 989)
# outputs: Tensor("mask_rcnn/res2b_branch2c/BiasAdd:0", shape=(None, 256, 256, 256), dtype=float32)
# ----------------------------debug base_layer.py 983
# str(self.name): bn2b_branch2c
# The caller function is 'error_handler' in module 'keras.utils.traceback_utils' (current in base_layer.py 989)
# args: (<tf.Tensor 'mask_rcnn/res2b_branch2c/BiasAdd:0' shape=(None, 256, 256, 256) dtype=float32>,)
# kwargs: {'training': False}
# ----------------------------debug base_layer.py 1009
# ----------------------------debug base_layer.py 1011
# ----------------------------debug base_layer.py 1013
# ----------------------------debug base_layer.py 1048
# ----------------------------debug base_layer.py 1112
# inputs: Tensor("mask_rcnn/res2b_branch2c/BiasAdd:0", shape=(None, 256, 256, 256), dtype=float32)
# ----------------------------debug traceback_utils.py 101
# The caller function is '__call__' in module 'keras.engine.base_layer' (current in base_layer.py 989)
# outputs: Tensor("mask_rcnn/bn2b_branch2c/FusedBatchNormV3:0", shape=(None, 256, 256, 256), dtype=float32)
# ----------------------------debug base_layer.py 983
# str(self.name): add_1
# The caller function is 'error_handler' in module 'keras.utils.traceback_utils' (current in base_layer.py 989)
# args: ([<tf.Tensor 'mask_rcnn/bn2b_branch2c/FusedBatchNormV3:0' shape=(None, 256, 256, 256) dtype=float32>, <tf.Tensor 'mask_rcnn/res2a_out/Relu:0' shape=(None, 256, 256, 256) dtype=float32>],)
# kwargs: {}
# ----------------------------debug base_layer.py 1009
# ----------------------------debug base_layer.py 1011
# ----------------------------debug base_layer.py 1013
# ----------------------------debug base_layer.py 1048
# ----------------------------debug base_layer.py 1112
# inputs: [<tf.Tensor 'mask_rcnn/bn2b_branch2c/FusedBatchNormV3:0' shape=(None, 256, 256, 256) dtype=float32>, <tf.Tensor 'mask_rcnn/res2a_out/Relu:0' shape=(None, 256, 256, 256) dtype=float32>]
# ----------------------------debug traceback_utils.py 101
# The caller function is '__call__' in module 'keras.engine.base_layer' (current in base_layer.py 989)
# outputs: Tensor("mask_rcnn/add_1/add:0", shape=(None, 256, 256, 256), dtype=float32)
# ----------------------------debug base_layer.py 983
# str(self.name): res2b_out
# The caller function is 'error_handler' in module 'keras.utils.traceback_utils' (current in base_layer.py 989)
# args: (<tf.Tensor 'mask_rcnn/add_1/add:0' shape=(None, 256, 256, 256) dtype=float32>,)
# kwargs: {}
# ----------------------------debug base_layer.py 1009
# ----------------------------debug base_layer.py 1011
# ----------------------------debug base_layer.py 1013
# ----------------------------debug base_layer.py 1048
# ----------------------------debug base_layer.py 1112
# inputs: Tensor("mask_rcnn/add_1/add:0", shape=(None, 256, 256, 256), dtype=float32)
# ----------------------------debug traceback_utils.py 101
# The caller function is '__call__' in module 'keras.engine.base_layer' (current in base_layer.py 989)
# outputs: Tensor("mask_rcnn/res2b_out/Relu:0", shape=(None, 256, 256, 256), dtype=float32)
# ----------------------------debug base_layer.py 983
# str(self.name): res2c_branch2a
# The caller function is 'error_handler' in module 'keras.utils.traceback_utils' (current in base_layer.py 989)
# args: (<tf.Tensor 'mask_rcnn/res2b_out/Relu:0' shape=(None, 256, 256, 256) dtype=float32>,)
# kwargs: {}
# ----------------------------debug base_layer.py 1009
# ----------------------------debug base_layer.py 1011
# ----------------------------debug base_layer.py 1013
# ----------------------------debug base_layer.py 1048
# ----------------------------debug base_layer.py 1112
# inputs: Tensor("mask_rcnn/res2b_out/Relu:0", shape=(None, 256, 256, 256), dtype=float32)
# ----------------------------debug traceback_utils.py 101
# The caller function is '__call__' in module 'keras.engine.base_layer' (current in base_layer.py 989)
# outputs: Tensor("mask_rcnn/res2c_branch2a/BiasAdd:0", shape=(None, 256, 256, 64), dtype=float32)
# ----------------------------debug base_layer.py 983
# str(self.name): bn2c_branch2a
# The caller function is 'error_handler' in module 'keras.utils.traceback_utils' (current in base_layer.py 989)
# args: (<tf.Tensor 'mask_rcnn/res2c_branch2a/BiasAdd:0' shape=(None, 256, 256, 64) dtype=float32>,)
# kwargs: {'training': False}
# ----------------------------debug base_layer.py 1009
# ----------------------------debug base_layer.py 1011
# ----------------------------debug base_layer.py 1013
# ----------------------------debug base_layer.py 1048
# ----------------------------debug base_layer.py 1112
# inputs: Tensor("mask_rcnn/res2c_branch2a/BiasAdd:0", shape=(None, 256, 256, 64), dtype=float32)
# ----------------------------debug traceback_utils.py 101
# The caller function is '__call__' in module 'keras.engine.base_layer' (current in base_layer.py 989)
# outputs: Tensor("mask_rcnn/bn2c_branch2a/FusedBatchNormV3:0", shape=(None, 256, 256, 64), dtype=float32)
# ----------------------------debug base_layer.py 983
# str(self.name): activation_5
# The caller function is 'error_handler' in module 'keras.utils.traceback_utils' (current in base_layer.py 989)
# args: (<tf.Tensor 'mask_rcnn/bn2c_branch2a/FusedBatchNormV3:0' shape=(None, 256, 256, 64) dtype=float32>,)
# kwargs: {}
# ----------------------------debug base_layer.py 1009
# ----------------------------debug base_layer.py 1011
# ----------------------------debug base_layer.py 1013
# ----------------------------debug base_layer.py 1048
# ----------------------------debug base_layer.py 1112
# inputs: Tensor("mask_rcnn/bn2c_branch2a/FusedBatchNormV3:0", shape=(None, 256, 256, 64), dtype=float32)
# ----------------------------debug traceback_utils.py 101
# The caller function is '__call__' in module 'keras.engine.base_layer' (current in base_layer.py 989)
# outputs: Tensor("mask_rcnn/activation_5/Relu:0", shape=(None, 256, 256, 64), dtype=float32)
# ----------------------------debug base_layer.py 983
# str(self.name): res2c_branch2b
# The caller function is 'error_handler' in module 'keras.utils.traceback_utils' (current in base_layer.py 989)
# args: (<tf.Tensor 'mask_rcnn/activation_5/Relu:0' shape=(None, 256, 256, 64) dtype=float32>,)
# kwargs: {}
# ----------------------------debug base_layer.py 1009
# ----------------------------debug base_layer.py 1011
# ----------------------------debug base_layer.py 1013
# ----------------------------debug base_layer.py 1048
# ----------------------------debug base_layer.py 1112
# inputs: Tensor("mask_rcnn/activation_5/Relu:0", shape=(None, 256, 256, 64), dtype=float32)
# ----------------------------debug traceback_utils.py 101
# The caller function is '__call__' in module 'keras.engine.base_layer' (current in base_layer.py 989)
# outputs: Tensor("mask_rcnn/res2c_branch2b/BiasAdd:0", shape=(None, 256, 256, 64), dtype=float32)
# ----------------------------debug base_layer.py 983
# str(self.name): bn2c_branch2b
# The caller function is 'error_handler' in module 'keras.utils.traceback_utils' (current in base_layer.py 989)
# args: (<tf.Tensor 'mask_rcnn/res2c_branch2b/BiasAdd:0' shape=(None, 256, 256, 64) dtype=float32>,)
# kwargs: {'training': False}
# ----------------------------debug base_layer.py 1009
# ----------------------------debug base_layer.py 1011
# ----------------------------debug base_layer.py 1013
# ----------------------------debug base_layer.py 1048
# ----------------------------debug base_layer.py 1112
# inputs: Tensor("mask_rcnn/res2c_branch2b/BiasAdd:0", shape=(None, 256, 256, 64), dtype=float32)
# ----------------------------debug traceback_utils.py 101
# The caller function is '__call__' in module 'keras.engine.base_layer' (current in base_layer.py 989)
# outputs: Tensor("mask_rcnn/bn2c_branch2b/FusedBatchNormV3:0", shape=(None, 256, 256, 64), dtype=float32)
# ----------------------------debug base_layer.py 983
# str(self.name): activation_6
# The caller function is 'error_handler' in module 'keras.utils.traceback_utils' (current in base_layer.py 989)
# args: (<tf.Tensor 'mask_rcnn/bn2c_branch2b/FusedBatchNormV3:0' shape=(None, 256, 256, 64) dtype=float32>,)
# kwargs: {}
# ----------------------------debug base_layer.py 1009
# ----------------------------debug base_layer.py 1011
# ----------------------------debug base_layer.py 1013
# ----------------------------debug base_layer.py 1048
# ----------------------------debug base_layer.py 1112
# inputs: Tensor("mask_rcnn/bn2c_branch2b/FusedBatchNormV3:0", shape=(None, 256, 256, 64), dtype=float32)
# ----------------------------debug traceback_utils.py 101
# The caller function is '__call__' in module 'keras.engine.base_layer' (current in base_layer.py 989)
# outputs: Tensor("mask_rcnn/activation_6/Relu:0", shape=(None, 256, 256, 64), dtype=float32)
# ----------------------------debug base_layer.py 983
# str(self.name): res2c_branch2c
# The caller function is 'error_handler' in module 'keras.utils.traceback_utils' (current in base_layer.py 989)
# args: (<tf.Tensor 'mask_rcnn/activation_6/Relu:0' shape=(None, 256, 256, 64) dtype=float32>,)
# kwargs: {}
# ----------------------------debug base_layer.py 1009
# ----------------------------debug base_layer.py 1011
# ----------------------------debug base_layer.py 1013
# ----------------------------debug base_layer.py 1048
# ----------------------------debug base_layer.py 1112
# inputs: Tensor("mask_rcnn/activation_6/Relu:0", shape=(None, 256, 256, 64), dtype=float32)
# ----------------------------debug traceback_utils.py 101
# The caller function is '__call__' in module 'keras.engine.base_layer' (current in base_layer.py 989)
# outputs: Tensor("mask_rcnn/res2c_branch2c/BiasAdd:0", shape=(None, 256, 256, 256), dtype=float32)
# ----------------------------debug base_layer.py 983
# str(self.name): bn2c_branch2c
# The caller function is 'error_handler' in module 'keras.utils.traceback_utils' (current in base_layer.py 989)
# args: (<tf.Tensor 'mask_rcnn/res2c_branch2c/BiasAdd:0' shape=(None, 256, 256, 256) dtype=float32>,)
# kwargs: {'training': False}
# ----------------------------debug base_layer.py 1009
# ----------------------------debug base_layer.py 1011
# ----------------------------debug base_layer.py 1013
# ----------------------------debug base_layer.py 1048
# ----------------------------debug base_layer.py 1112
# inputs: Tensor("mask_rcnn/res2c_branch2c/BiasAdd:0", shape=(None, 256, 256, 256), dtype=float32)
# ----------------------------debug traceback_utils.py 101
# The caller function is '__call__' in module 'keras.engine.base_layer' (current in base_layer.py 989)
# outputs: Tensor("mask_rcnn/bn2c_branch2c/FusedBatchNormV3:0", shape=(None, 256, 256, 256), dtype=float32)
# ----------------------------debug base_layer.py 983
# str(self.name): add_2
# The caller function is 'error_handler' in module 'keras.utils.traceback_utils' (current in base_layer.py 989)
# args: ([<tf.Tensor 'mask_rcnn/bn2c_branch2c/FusedBatchNormV3:0' shape=(None, 256, 256, 256) dtype=float32>, <tf.Tensor 'mask_rcnn/res2b_out/Relu:0' shape=(None, 256, 256, 256) dtype=float32>],)
# kwargs: {}
# ----------------------------debug base_layer.py 1009
# ----------------------------debug base_layer.py 1011
# ----------------------------debug base_layer.py 1013
# ----------------------------debug base_layer.py 1048
# ----------------------------debug base_layer.py 1112
# inputs: [<tf.Tensor 'mask_rcnn/bn2c_branch2c/FusedBatchNormV3:0' shape=(None, 256, 256, 256) dtype=float32>, <tf.Tensor 'mask_rcnn/res2b_out/Relu:0' shape=(None, 256, 256, 256) dtype=float32>]
# ----------------------------debug traceback_utils.py 101
# The caller function is '__call__' in module 'keras.engine.base_layer' (current in base_layer.py 989)
# outputs: Tensor("mask_rcnn/add_2/add:0", shape=(None, 256, 256, 256), dtype=float32)
# ----------------------------debug base_layer.py 983
# str(self.name): res2c_out
# The caller function is 'error_handler' in module 'keras.utils.traceback_utils' (current in base_layer.py 989)
# args: (<tf.Tensor 'mask_rcnn/add_2/add:0' shape=(None, 256, 256, 256) dtype=float32>,)
# kwargs: {}
# ----------------------------debug base_layer.py 1009
# ----------------------------debug base_layer.py 1011
# ----------------------------debug base_layer.py 1013
# ----------------------------debug base_layer.py 1048
# ----------------------------debug base_layer.py 1112
# inputs: Tensor("mask_rcnn/add_2/add:0", shape=(None, 256, 256, 256), dtype=float32)
# ----------------------------debug traceback_utils.py 101
# The caller function is '__call__' in module 'keras.engine.base_layer' (current in base_layer.py 989)
# outputs: Tensor("mask_rcnn/res2c_out/Relu:0", shape=(None, 256, 256, 256), dtype=float32)
# ----------------------------debug base_layer.py 983
# str(self.name): res3a_branch2a
# The caller function is 'error_handler' in module 'keras.utils.traceback_utils' (current in base_layer.py 989)
# args: (<tf.Tensor 'mask_rcnn/res2c_out/Relu:0' shape=(None, 256, 256, 256) dtype=float32>,)
# kwargs: {}
# ----------------------------debug base_layer.py 1009
# ----------------------------debug base_layer.py 1011
# ----------------------------debug base_layer.py 1013
# ----------------------------debug base_layer.py 1048
# ----------------------------debug base_layer.py 1112
# inputs: Tensor("mask_rcnn/res2c_out/Relu:0", shape=(None, 256, 256, 256), dtype=float32)
# ----------------------------debug traceback_utils.py 101
# The caller function is '__call__' in module 'keras.engine.base_layer' (current in base_layer.py 989)
# outputs: Tensor("mask_rcnn/res3a_branch2a/BiasAdd:0", shape=(None, 128, 128, 128), dtype=float32)
# ----------------------------debug base_layer.py 983
# str(self.name): bn3a_branch2a
# The caller function is 'error_handler' in module 'keras.utils.traceback_utils' (current in base_layer.py 989)
# args: (<tf.Tensor 'mask_rcnn/res3a_branch2a/BiasAdd:0' shape=(None, 128, 128, 128) dtype=float32>,)
# kwargs: {'training': False}
# ----------------------------debug base_layer.py 1009
# ----------------------------debug base_layer.py 1011
# ----------------------------debug base_layer.py 1013
# ----------------------------debug base_layer.py 1048
# ----------------------------debug base_layer.py 1112
# inputs: Tensor("mask_rcnn/res3a_branch2a/BiasAdd:0", shape=(None, 128, 128, 128), dtype=float32)
# ----------------------------debug traceback_utils.py 101
# The caller function is '__call__' in module 'keras.engine.base_layer' (current in base_layer.py 989)
# outputs: Tensor("mask_rcnn/bn3a_branch2a/FusedBatchNormV3:0", shape=(None, 128, 128, 128), dtype=float32)
# ----------------------------debug base_layer.py 983
# str(self.name): activation_7
# The caller function is 'error_handler' in module 'keras.utils.traceback_utils' (current in base_layer.py 989)
# args: (<tf.Tensor 'mask_rcnn/bn3a_branch2a/FusedBatchNormV3:0' shape=(None, 128, 128, 128) dtype=float32>,)
# kwargs: {}
# ----------------------------debug base_layer.py 1009
# ----------------------------debug base_layer.py 1011
# ----------------------------debug base_layer.py 1013
# ----------------------------debug base_layer.py 1048
# ----------------------------debug base_layer.py 1112
# inputs: Tensor("mask_rcnn/bn3a_branch2a/FusedBatchNormV3:0", shape=(None, 128, 128, 128), dtype=float32)
# ----------------------------debug traceback_utils.py 101
# The caller function is '__call__' in module 'keras.engine.base_layer' (current in base_layer.py 989)
# outputs: Tensor("mask_rcnn/activation_7/Relu:0", shape=(None, 128, 128, 128), dtype=float32)
# ----------------------------debug base_layer.py 983
# str(self.name): res3a_branch2b
# The caller function is 'error_handler' in module 'keras.utils.traceback_utils' (current in base_layer.py 989)
# args: (<tf.Tensor 'mask_rcnn/activation_7/Relu:0' shape=(None, 128, 128, 128) dtype=float32>,)
# kwargs: {}
# ----------------------------debug base_layer.py 1009
# ----------------------------debug base_layer.py 1011
# ----------------------------debug base_layer.py 1013
# ----------------------------debug base_layer.py 1048
# ----------------------------debug base_layer.py 1112
# inputs: Tensor("mask_rcnn/activation_7/Relu:0", shape=(None, 128, 128, 128), dtype=float32)
# ----------------------------debug traceback_utils.py 101
# The caller function is '__call__' in module 'keras.engine.base_layer' (current in base_layer.py 989)
# outputs: Tensor("mask_rcnn/res3a_branch2b/BiasAdd:0", shape=(None, 128, 128, 128), dtype=float32)
# ----------------------------debug base_layer.py 983
# str(self.name): bn3a_branch2b
# The caller function is 'error_handler' in module 'keras.utils.traceback_utils' (current in base_layer.py 989)
# args: (<tf.Tensor 'mask_rcnn/res3a_branch2b/BiasAdd:0' shape=(None, 128, 128, 128) dtype=float32>,)
# kwargs: {'training': False}
# ----------------------------debug base_layer.py 1009
# ----------------------------debug base_layer.py 1011
# ----------------------------debug base_layer.py 1013
# ----------------------------debug base_layer.py 1048
# ----------------------------debug base_layer.py 1112
# inputs: Tensor("mask_rcnn/res3a_branch2b/BiasAdd:0", shape=(None, 128, 128, 128), dtype=float32)
# ----------------------------debug traceback_utils.py 101
# The caller function is '__call__' in module 'keras.engine.base_layer' (current in base_layer.py 989)
# outputs: Tensor("mask_rcnn/bn3a_branch2b/FusedBatchNormV3:0", shape=(None, 128, 128, 128), dtype=float32)
# ----------------------------debug base_layer.py 983
# str(self.name): activation_8
# The caller function is 'error_handler' in module 'keras.utils.traceback_utils' (current in base_layer.py 989)
# args: (<tf.Tensor 'mask_rcnn/bn3a_branch2b/FusedBatchNormV3:0' shape=(None, 128, 128, 128) dtype=float32>,)
# kwargs: {}
# ----------------------------debug base_layer.py 1009
# ----------------------------debug base_layer.py 1011
# ----------------------------debug base_layer.py 1013
# ----------------------------debug base_layer.py 1048
# ----------------------------debug base_layer.py 1112
# inputs: Tensor("mask_rcnn/bn3a_branch2b/FusedBatchNormV3:0", shape=(None, 128, 128, 128), dtype=float32)
# ----------------------------debug traceback_utils.py 101
# The caller function is '__call__' in module 'keras.engine.base_layer' (current in base_layer.py 989)
# outputs: Tensor("mask_rcnn/activation_8/Relu:0", shape=(None, 128, 128, 128), dtype=float32)
# ----------------------------debug base_layer.py 983
# str(self.name): res3a_branch1
# The caller function is 'error_handler' in module 'keras.utils.traceback_utils' (current in base_layer.py 989)
# args: (<tf.Tensor 'mask_rcnn/res2c_out/Relu:0' shape=(None, 256, 256, 256) dtype=float32>,)
# kwargs: {}
# ----------------------------debug base_layer.py 1009
# ----------------------------debug base_layer.py 1011
# ----------------------------debug base_layer.py 1013
# ----------------------------debug base_layer.py 1048
# ----------------------------debug base_layer.py 1112
# inputs: Tensor("mask_rcnn/res2c_out/Relu:0", shape=(None, 256, 256, 256), dtype=float32)
# ----------------------------debug traceback_utils.py 101
# The caller function is '__call__' in module 'keras.engine.base_layer' (current in base_layer.py 989)
# outputs: Tensor("mask_rcnn/res3a_branch1/BiasAdd:0", shape=(None, 128, 128, 512), dtype=float32)
# ----------------------------debug base_layer.py 983
# str(self.name): res3a_branch2c
# The caller function is 'error_handler' in module 'keras.utils.traceback_utils' (current in base_layer.py 989)
# args: (<tf.Tensor 'mask_rcnn/activation_8/Relu:0' shape=(None, 128, 128, 128) dtype=float32>,)
# kwargs: {}
# ----------------------------debug base_layer.py 1009
# ----------------------------debug base_layer.py 1011
# ----------------------------debug base_layer.py 1013
# ----------------------------debug base_layer.py 1048
# ----------------------------debug base_layer.py 1112
# inputs: Tensor("mask_rcnn/activation_8/Relu:0", shape=(None, 128, 128, 128), dtype=float32)
# ----------------------------debug traceback_utils.py 101
# The caller function is '__call__' in module 'keras.engine.base_layer' (current in base_layer.py 989)
# outputs: Tensor("mask_rcnn/res3a_branch2c/BiasAdd:0", shape=(None, 128, 128, 512), dtype=float32)
# ----------------------------debug base_layer.py 983
# str(self.name): bn3a_branch2c
# The caller function is 'error_handler' in module 'keras.utils.traceback_utils' (current in base_layer.py 989)
# args: (<tf.Tensor 'mask_rcnn/res3a_branch2c/BiasAdd:0' shape=(None, 128, 128, 512) dtype=float32>,)
# kwargs: {'training': False}
# ----------------------------debug base_layer.py 1009
# ----------------------------debug base_layer.py 1011
# ----------------------------debug base_layer.py 1013
# ----------------------------debug base_layer.py 1048
# ----------------------------debug base_layer.py 1112
# inputs: Tensor("mask_rcnn/res3a_branch2c/BiasAdd:0", shape=(None, 128, 128, 512), dtype=float32)
# ----------------------------debug traceback_utils.py 101
# The caller function is '__call__' in module 'keras.engine.base_layer' (current in base_layer.py 989)
# outputs: Tensor("mask_rcnn/bn3a_branch2c/FusedBatchNormV3:0", shape=(None, 128, 128, 512), dtype=float32)
# ----------------------------debug base_layer.py 983
# str(self.name): bn3a_branch1
# The caller function is 'error_handler' in module 'keras.utils.traceback_utils' (current in base_layer.py 989)
# args: (<tf.Tensor 'mask_rcnn/res3a_branch1/BiasAdd:0' shape=(None, 128, 128, 512) dtype=float32>,)
# kwargs: {'training': False}
# ----------------------------debug base_layer.py 1009
# ----------------------------debug base_layer.py 1011
# ----------------------------debug base_layer.py 1013
# ----------------------------debug base_layer.py 1048
# ----------------------------debug base_layer.py 1112
# inputs: Tensor("mask_rcnn/res3a_branch1/BiasAdd:0", shape=(None, 128, 128, 512), dtype=float32)
# ----------------------------debug traceback_utils.py 101
# The caller function is '__call__' in module 'keras.engine.base_layer' (current in base_layer.py 989)
# outputs: Tensor("mask_rcnn/bn3a_branch1/FusedBatchNormV3:0", shape=(None, 128, 128, 512), dtype=float32)
# ----------------------------debug base_layer.py 983
# str(self.name): add_3
# The caller function is 'error_handler' in module 'keras.utils.traceback_utils' (current in base_layer.py 989)
# args: ([<tf.Tensor 'mask_rcnn/bn3a_branch2c/FusedBatchNormV3:0' shape=(None, 128, 128, 512) dtype=float32>, <tf.Tensor 'mask_rcnn/bn3a_branch1/FusedBatchNormV3:0' shape=(None, 128, 128, 512) dtype=float32>],)
# kwargs: {}
# ----------------------------debug base_layer.py 1009
# ----------------------------debug base_layer.py 1011
# ----------------------------debug base_layer.py 1013
# ----------------------------debug base_layer.py 1048
# ----------------------------debug base_layer.py 1112
# inputs: [<tf.Tensor 'mask_rcnn/bn3a_branch2c/FusedBatchNormV3:0' shape=(None, 128, 128, 512) dtype=float32>, <tf.Tensor 'mask_rcnn/bn3a_branch1/FusedBatchNormV3:0' shape=(None, 128, 128, 512) dtype=float32>]
# ----------------------------debug traceback_utils.py 101
# ...
# ----------------------------debug func_graph.py 1187
# The caller function is '_create_graph_function' in module 'tensorflow.python.eager.function'
# ----------------------------debug function.py 2654
# The caller function is '_maybe_define_function' in module 'tensorflow.python.eager.function'
# ----------------------------debug func_graph.py 1187
# The caller function is '_create_graph_function' in module 'tensorflow.python.eager.function'
# ----------------------------debug function.py 2654
# The caller function is '_maybe_define_function' in module 'tensorflow.python.eager.function'
# ----------------------------debug func_graph.py 1187
# The caller function is '_create_graph_function' in module 'tensorflow.python.eager.function'
# Processing 1 images
# image                    shape: (800, 1280, 3)        min:    0.00000  max:  255.00000  uint8
# molded_images            shape: (1, 1024, 1024, 3)    min: -123.70000  max:  151.10000  float64
# image_metas              shape: (1, 93)               min:    0.00000  max: 1280.00000  float64
# anchors                  shape: (1, 261888, 4)        min:   -0.35390  max:    1.29134  float32
# ----------------------------debug function.py 2654
# The caller function is '_maybe_define_function' in module 'tensorflow.python.eager.function'
# ----------------------------debug func_graph.py 1187
# The caller function is '_create_graph_function' in module 'tensorflow.python.eager.function'
# ----------------------------debug function.py 2654
# The caller function is '_maybe_define_function' in module 'tensorflow.python.eager.function'
# ----------------------------debug func_graph.py 1187
# The caller function is '_create_graph_function' in module 'tensorflow.python.eager.function'
# ----------------------------debug function.py 2654
# The caller function is '_maybe_define_function' in module 'tensorflow.python.eager.function'
# ----------------------------debug func_graph.py 1187
# The caller function is '_create_graph_function' in module 'tensorflow.python.eager.function'
# Processing 1 images
# image                    shape: (800, 1280, 3)        min:    0.00000  max:  255.00000  uint8
# molded_images            shape: (1, 1024, 1024, 3)    min: -123.70000  max:  151.10000  float64
# image_metas              shape: (1, 93)               min:    0.00000  max: 1280.00000  float64
# anchors                  shape: (1, 261888, 4)        min:   -0.35390  max:    1.29134  float32
# ----------------------------debug function.py 2654
# The caller function is '_maybe_define_function' in module 'tensorflow.python.eager.function'
# ----------------------------debug func_graph.py 1187
# The caller function is '_create_graph_function' in module 'tensorflow.python.eager.function'
# ----------------------------debug function.py 2654
# The caller function is '_maybe_define_function' in module 'tensorflow.python.eager.function'
# ----------------------------debug func_graph.py 1187
# The caller function is '_create_graph_function' in module 'tensorflow.python.eager.function'
# ----------------------------debug function.py 2654
# The caller function is '_maybe_define_function' in module 'tensorflow.python.eager.function'
# ----------------------------debug func_graph.py 1187
# The caller function is '_create_graph_function' in module 'tensorflow.python.eager.function'
# Processing 1 images
# image                    shape: (800, 1280, 3)        min:    0.00000  max:  255.00000  uint8
# molded_images            shape: (1, 1024, 1024, 3)    min: -123.70000  max:  151.10000  float64
# image_metas              shape: (1, 93)               min:    0.00000  max: 1280.00000  float64
# anchors                  shape: (1, 261888, 4)        min:   -0.35390  max:    1.29134  float32
# ----------------------------debug function.py 2654
# The caller function is '_maybe_define_function' in module 'tensorflow.python.eager.function'
# ----------------------------debug func_graph.py 1187
# The caller function is '_create_graph_function' in module 'tensorflow.python.eager.function'
# ----------------------------debug function.py 2654
# The caller function is '_maybe_define_function' in module 'tensorflow.python.eager.function'
# ----------------------------debug func_graph.py 1187
# The caller function is '_create_graph_function' in module 'tensorflow.python.eager.function'
# ----------------------------debug function.py 2654
# The caller function is '_maybe_define_function' in module 'tensorflow.python.eager.function'
# ----------------------------debug func_graph.py 1187
# The caller function is '_create_graph_function' in module 'tensorflow.python.eager.function'
# Processing 1 images
# image                    shape: (800, 1280, 3)        min:    0.00000  max:  255.00000  uint8
# molded_images            shape: (1, 1024, 1024, 3)    min: -123.70000  max:  151.10000  float64
# image_metas              shape: (1, 93)               min:    0.00000  max: 1280.00000  float64
# anchors                  shape: (1, 261888, 4)        min:   -0.35390  max:    1.29134  float32
# ----------------------------debug function.py 2654
# The caller function is '_maybe_define_function' in module 'tensorflow.python.eager.function'
# ----------------------------debug func_graph.py 1187
# The caller function is '_create_graph_function' in module 'tensorflow.python.eager.function'
# ----------------------------debug function.py 2654
# The caller function is '_maybe_define_function' in module 'tensorflow.python.eager.function'
# ----------------------------debug func_graph.py 1187
# The caller function is '_create_graph_function' in module 'tensorflow.python.eager.function'
# ----------------------------debug function.py 2654
# The caller function is '_maybe_define_function' in module 'tensorflow.python.eager.function'
# ----------------------------debug func_graph.py 1187
# The caller function is '_create_graph_function' in module 'tensorflow.python.eager.function'
# Processing 1 images
# image                    shape: (800, 1280, 3)        min:    0.00000  max:  255.00000  uint8
# molded_images            shape: (1, 1024, 1024, 3)    min: -123.70000  max:  151.10000  float64
# image_metas              shape: (1, 93)               min:    0.00000  max: 1280.00000  float64
# anchors                  shape: (1, 261888, 4)        min:   -0.35390  max:    1.29134  float32
# ----------------------------debug function.py 2654
# The caller function is '_maybe_define_function' in module 'tensorflow.python.eager.function'
# ----------------------------debug func_graph.py 1187
# The caller function is '_create_graph_function' in module 'tensorflow.python.eager.function'
# ----------------------------debug function.py 2654
# The caller function is '_maybe_define_function' in module 'tensorflow.python.eager.function'
# ----------------------------debug func_graph.py 1187
# The caller function is '_create_graph_function' in module 'tensorflow.python.eager.function'
# ----------------------------debug function.py 2654
# The caller function is '_maybe_define_function' in module 'tensorflow.python.eager.function'
# ----------------------------debug func_graph.py 1187
# The caller function is '_create_graph_function' in module 'tensorflow.python.eager.function'
# Processing 1 images
# image                    shape: (800, 1280, 3)        min:    0.00000  max:  255.00000  uint8
# molded_images            shape: (1, 1024, 1024, 3)    min: -123.70000  max:  151.10000  float64
# image_metas              shape: (1, 93)               min:    0.00000  max: 1280.00000  float64
# anchors                  shape: (1, 261888, 4)        min:   -0.35390  max:    1.29134  float32
# ----------------------------debug function.py 2654
# The caller function is '_maybe_define_function' in module 'tensorflow.python.eager.function'
# ----------------------------debug func_graph.py 1187
# The caller function is '_create_graph_function' in module 'tensorflow.python.eager.function'
# ----------------------------debug function.py 2654
# The caller function is '_maybe_define_function' in module 'tensorflow.python.eager.function'
# ----------------------------debug func_graph.py 1187
# The caller function is '_create_graph_function' in module 'tensorflow.python.eager.function'
# ----------------------------debug function.py 2654
# The caller function is '_maybe_define_function' in module 'tensorflow.python.eager.function'
# ----------------------------debug func_graph.py 1187
# The caller function is '_create_graph_function' in module 'tensorflow.python.eager.function'
# Processing 1 images
# image                    shape: (800, 1280, 3)        min:    0.00000  max:  255.00000  uint8
# molded_images            shape: (1, 1024, 1024, 3)    min: -123.70000  max:  151.10000  float64
# image_metas              shape: (1, 93)               min:    0.00000  max: 1280.00000  float64
# anchors                  shape: (1, 261888, 4)        min:   -0.35390  max:    1.29134  float32
# ----------------------------debug function.py 2654
# The caller function is '_maybe_define_function' in module 'tensorflow.python.eager.function'
# ----------------------------debug func_graph.py 1187
# The caller function is '_create_graph_function' in module 'tensorflow.python.eager.function'
# ----------------------------debug function.py 2654
# The caller function is '_maybe_define_function' in module 'tensorflow.python.eager.function'
# ----------------------------debug func_graph.py 1187
# The caller function is '_create_graph_function' in module 'tensorflow.python.eager.function'
# ----------------------------debug function.py 2654
# The caller function is '_maybe_define_function' in module 'tensorflow.python.eager.function'
# ----------------------------debug func_graph.py 1187
# The caller function is '_create_graph_function' in module 'tensorflow.python.eager.function'
# Processing 1 images
# image                    shape: (800, 1280, 3)        min:    0.00000  max:  255.00000  uint8
# molded_images            shape: (1, 1024, 1024, 3)    min: -123.70000  max:  151.10000  float64
# image_metas              shape: (1, 93)               min:    0.00000  max: 1280.00000  float64
# anchors                  shape: (1, 261888, 4)        min:   -0.35390  max:    1.29134  float32
# ----------------------------debug function.py 2654
# The caller function is '_maybe_define_function' in module 'tensorflow.python.eager.function'
# ----------------------------debug func_graph.py 1187
# The caller function is '_create_graph_function' in module 'tensorflow.python.eager.function'
# ----------------------------debug function.py 2654
# The caller function is '_maybe_define_function' in module 'tensorflow.python.eager.function'
# ----------------------------debug func_graph.py 1187
# The caller function is '_create_graph_function' in module 'tensorflow.python.eager.function'
# ----------------------------debug function.py 2654
# The caller function is '_maybe_define_function' in module 'tensorflow.python.eager.function'
# ----------------------------debug func_graph.py 1187
# The caller function is '_create_graph_function' in module 'tensorflow.python.eager.function'
# Processing 1 images
# image                    shape: (800, 1280, 3)        min:    0.00000  max:  255.00000  uint8
# molded_images            shape: (1, 1024, 1024, 3)    min: -123.70000  max:  151.10000  float64
# image_metas              shape: (1, 93)               min:    0.00000  max: 1280.00000  float64
# anchors                  shape: (1, 261888, 4)        min:   -0.35390  max:    1.29134  float32
# ----------------------------debug function.py 2654
# The caller function is '_maybe_define_function' in module 'tensorflow.python.eager.function'
# ----------------------------debug func_graph.py 1187
# The caller function is '_create_graph_function' in module 'tensorflow.python.eager.function'
# ----------------------------debug function.py 2654
# The caller function is '_maybe_define_function' in module 'tensorflow.python.eager.function'
# ----------------------------debug func_graph.py 1187
# The caller function is '_create_graph_function' in module 'tensorflow.python.eager.function'
# ----------------------------debug function.py 2654
# The caller function is '_maybe_define_function' in module 'tensorflow.python.eager.function'
# ----------------------------debug func_graph.py 1187
# The caller function is '_create_graph_function' in module 'tensorflow.python.eager.function'
# Processing 1 images
# image                    shape: (800, 1280, 3)        min:    0.00000  max:  255.00000  uint8
# molded_images            shape: (1, 1024, 1024, 3)    min: -123.70000  max:  151.10000  float64
# image_metas              shape: (1, 93)               min:    0.00000  max: 1280.00000  float64
# anchors                  shape: (1, 261888, 4)        min:   -0.35390  max:    1.29134  float32
# ----------------------------debug function.py 2654
# The caller function is '_maybe_define_function' in module 'tensorflow.python.eager.function'
# ----------------------------debug func_graph.py 1187
# The caller function is '_create_graph_function' in module 'tensorflow.python.eager.function'
# ----------------------------debug function.py 2654
# The caller function is '_maybe_define_function' in module 'tensorflow.python.eager.function'
# ----------------------------debug func_graph.py 1187
# The caller function is '_create_graph_function' in module 'tensorflow.python.eager.function'
# ----------------------------debug function.py 2654
# The caller function is '_maybe_define_function' in module 'tensorflow.python.eager.function'
# ----------------------------debug func_graph.py 1187
# The caller function is '_create_graph_function' in module 'tensorflow.python.eager.function'
# Processing 1 images
# image                    shape: (800, 1280, 3)        min:    0.00000  max:  255.00000  uint8
# molded_images            shape: (1, 1024, 1024, 3)    min: -123.70000  max:  151.10000  float64
# image_metas              shape: (1, 93)               min:    0.00000  max: 1280.00000  float64
# anchors                  shape: (1, 261888, 4)        min:   -0.35390  max:    1.29134  float32
# ----------------------------debug function.py 2654
# The caller function is '_maybe_define_function' in module 'tensorflow.python.eager.function'
# ----------------------------debug func_graph.py 1187
# The caller function is '_create_graph_function' in module 'tensorflow.python.eager.function'
# ----------------------------debug function.py 2654
# The caller function is '_maybe_define_function' in module 'tensorflow.python.eager.function'
# ----------------------------debug func_graph.py 1187
# The caller function is '_create_graph_function' in module 'tensorflow.python.eager.function'
# ----------------------------debug function.py 2654
# The caller function is '_maybe_define_function' in module 'tensorflow.python.eager.function'
# ----------------------------debug func_graph.py 1187
# The caller function is '_create_graph_function' in module 'tensorflow.python.eager.function'
# Processing 1 images
# image                    shape: (800, 1280, 3)        min:    0.00000  max:  255.00000  uint8
# molded_images            shape: (1, 1024, 1024, 3)    min: -123.70000  max:  151.10000  float64
# image_metas              shape: (1, 93)               min:    0.00000  max: 1280.00000  float64
# anchors                  shape: (1, 261888, 4)        min:   -0.35390  max:    1.29134  float32
# ----------------------------debug function.py 2654
# The caller function is '_maybe_define_function' in module 'tensorflow.python.eager.function'
# ----------------------------debug func_graph.py 1187
# The caller function is '_create_graph_function' in module 'tensorflow.python.eager.function'
# ----------------------------debug function.py 2654
# The caller function is '_maybe_define_function' in module 'tensorflow.python.eager.function'
# ----------------------------debug func_graph.py 1187
# The caller function is '_create_graph_function' in module 'tensorflow.python.eager.function'
# ----------------------------debug function.py 2654
# The caller function is '_maybe_define_function' in module 'tensorflow.python.eager.function'
# ----------------------------debug func_graph.py 1187
# The caller function is '_create_graph_function' in module 'tensorflow.python.eager.function'
