# %%
import tensorflow as tf
from tensorflow.keras.layers import Input, Lambda
from tensorflow.keras.models import Model

# Input layer
input_layer = Input(shape=(1,))

# Inline lambda function within Lambda layer
output_layer = Lambda(lambda x: x * 2)(input_layer)

# Build the model
model = Model(inputs=input_layer, outputs=output_layer)

# Compile and print model summary
model.compile(optimizer='adam', loss='mse')
model.summary()
# Out:
# ----------------------------debug base_layer.py 983
# str(self.name): lambda
# The caller function is 'error_handler' in module 'keras.utils.traceback_utils' (current in base_layer.py 989)
# args: (<KerasTensor: shape=(None, 1) dtype=float32 (created by layer 'input_1')>,)
# kwargs: {}
# ----------------------------debug base_layer.py 1009
# ----------------------------debug base_layer.py 1011
# ----------------------------debug base_layer.py 1013
# ----------------------------debug base_layer.py 1023
# The caller function is '_functional_construction_call' in module 'keras.engine.base_layer' (current in base_layer.py 2358)
# The caller function is '<listcomp>' in module 'tensorflow.python.util.nest' (currently in keras_tensor.py 670)
# ----------------------------debug keras_tensor.py 243
# The caller function is 'keras_tensor_to_placeholder' in module 'keras.engine.keras_tensor' (currently in keras_tensor.py 248)
# keras_tensor.py self: KerasTensor(type_spec=TensorSpec(shape=(None, 1), dtype=tf.float32, name='input_1'), name='input_1', description="created by layer 'input_1'")
# component_to_placeholder: <function KerasTensor._to_placeholder.<locals>.component_to_placeholder at 0x000001817FEF3640>
# self.type_spec: TensorSpec(shape=(None, 1), dtype=tf.float32, name='input_1')
# The caller function is '<listcomp>' in module 'tensorflow.python.util.nest' (current in keras.engine.keras_tensor 238)
# The caller function is 'placeholder' in module 'tensorflow.python.ops.array_ops' (current in gen_array_ops.py 6902)
# name: None
# dtype: 1
# The caller function is '<listcomp>' in module 'tensorflow.python.util.nest' (currently in keras_tensor.py 670)
# The caller function is '<listcomp>' in module 'tensorflow.python.util.nest' (currently in keras_tensor.py 670)
# ----------------------------debug base_layer.py 2441
# ----------------------------debug traceback_utils.py 101
# The caller function is '_infer_output_signature' in module 'keras.engine.base_layer' (current in base_layer.py 989)
# ----------------------------debug base_layer.py 2462
# ----------------------------debug base_layer.py 2471
# ----------------------------debug functional.py 1102
# inputs: [<KerasTensor: shape=(None, 1) dtype=float32 (created by layer 'input_1')>]
# The caller function is '_init_graph_network' in module 'keras.engine.functional' (current in functional.py 1108)
# ----------------------------debug functional.py 1159
# len nodes_by_depth: 2
# layers_with_complete_input: ['lambda']
# Model: "model"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  input_1 (InputLayer)        [(None, 1)]               0
#
#  lambda (Lambda)             (None, 1)                 0
#
# =================================================================
# Total params: 0
# Trainable params: 0
# Non-trainable params: 0
# _________________________________________________________________

# %%
import tensorflow as tf
from tensorflow.keras.layers import Input, Lambda
from tensorflow.keras.models import Model

# Input layer
input_layer = Input(shape=(1,))

# Inline lambda function within Lambda layer
output_layer = Lambda(lambda x: x * 2)(input_layer)

# Build the model
model = Model(inputs=input_layer, outputs=output_layer)

# Compile the model
model.compile(optimizer='adam', loss='mse')

# Generate some example data
import numpy as np
x_train = np.array([[1.0], [2.0], [3.0], [4.0]])
y_train = x_train * 2

# Train the model
model.fit(x_train, y_train, epochs=100, verbose=1)

# Evaluate the model
loss = model.evaluate(x_train, y_train)
print("Final loss:", loss)
# Out:
# ----------------------------debug base_layer.py 983
# str(self.name): lambda_1
# The caller function is 'error_handler' in module 'keras.utils.traceback_utils' (current in base_layer.py 989)
# args: (<KerasTensor: shape=(None, 1) dtype=float32 (created by layer 'input_2')>,)
# kwargs: {}
# ----------------------------debug base_layer.py 1009
# ----------------------------debug base_layer.py 1011
# ----------------------------debug base_layer.py 1013
# ----------------------------debug base_layer.py 1023
# The caller function is '_functional_construction_call' in module 'keras.engine.base_layer' (current in base_layer.py 2358)
# The caller function is '<listcomp>' in module 'tensorflow.python.util.nest' (currently in keras_tensor.py 670)
# ----------------------------debug keras_tensor.py 243
# The caller function is 'keras_tensor_to_placeholder' in module 'keras.engine.keras_tensor' (currently in keras_tensor.py 248)
# keras_tensor.py self: KerasTensor(type_spec=TensorSpec(shape=(None, 1), dtype=tf.float32, name='input_2'), name='input_2', description="created by layer 'input_2'")
# component_to_placeholder: <function KerasTensor._to_placeholder.<locals>.component_to_placeholder at 0x000001817FEF3D00>
# self.type_spec: TensorSpec(shape=(None, 1), dtype=tf.float32, name='input_2')
# The caller function is '<listcomp>' in module 'tensorflow.python.util.nest' (current in keras.engine.keras_tensor 238)
# The caller function is 'placeholder' in module 'tensorflow.python.ops.array_ops' (current in gen_array_ops.py 6902)
# name: None
# dtype: 1
# The caller function is '<listcomp>' in module 'tensorflow.python.util.nest' (currently in keras_tensor.py 670)
# The caller function is '<listcomp>' in module 'tensorflow.python.util.nest' (currently in keras_tensor.py 670)
# ----------------------------debug base_layer.py 2441
# ----------------------------debug traceback_utils.py 101
# The caller function is '_infer_output_signature' in module 'keras.engine.base_layer' (current in base_layer.py 989)
# ----------------------------debug base_layer.py 2462
# ----------------------------debug base_layer.py 2471
# ----------------------------debug functional.py 1102
# inputs: [<KerasTensor: shape=(None, 1) dtype=float32 (created by layer 'input_2')>]
# The caller function is '_init_graph_network' in module 'keras.engine.functional' (current in functional.py 1108)
# ----------------------------debug functional.py 1159
# len nodes_by_depth: 2
# layers_with_complete_input: ['lambda_1']
# ----------------------------debug training.py 1508
# The caller function is 'error_handler' in module 'keras.utils.traceback_utils'
# ----------------------------debug function.py 2654
# The caller function is '_maybe_define_function' in module 'tensorflow.python.eager.function'
# ----------------------------debug func_graph.py 1187
# The caller function is '_create_graph_function' in module 'tensorflow.python.eager.function'
# ----------------------------debug api.py 321
# The caller function is 'wrapper' in module 'tensorflow.python.autograph.impl.api'
# ----------------------------debug api.py 451
# The caller function is 'converted_call' in module 'tensorflow.python.autograph.impl.api'
# ----------------------------debug function.py 2654
# The caller function is '_maybe_define_function' in module 'tensorflow.python.eager.function'
# ----------------------------debug func_graph.py 1187
# The caller function is '_create_graph_function' in module 'tensorflow.python.eager.function'
# ----------------------------debug api.py 321
# The caller function is 'wrapper' in module 'tensorflow.python.autograph.impl.api'
# ----------------------------debug api.py 451
# The caller function is 'converted_call' in module 'tensorflow.python.autograph.impl.api'
# ----------------------------debug function.py 2654
# The caller function is '_maybe_define_function' in module 'tensorflow.python.eager.function'
# ----------------------------debug func_graph.py 1187
# The caller function is '_create_graph_function' in module 'tensorflow.python.eager.function'
# ----------------------------debug api.py 321
# The caller function is 'wrapper' in module 'tensorflow.python.autograph.impl.api'
# ----------------------------debug api.py 451
# The caller function is 'converted_call' in module 'tensorflow.python.autograph.impl.api'
# Epoch 1/100
# ----------------------------debug def_function.py 755
# The caller function is '_call' in module 'tensorflow.python.eager.def_function'
# ----------------------------debug function.py 2520
# The caller function is '_initialize' in module 'tensorflow.python.eager.def_function'
# ----------------------------debug function.py 2654
# The caller function is '_maybe_define_function' in module 'tensorflow.python.eager.function'
# ----------------------------debug func_graph.py 1187
# The caller function is '_create_graph_function' in module 'tensorflow.python.eager.function'
# ----------------------------debug def_function.py 672
# The caller function is 'func_graph_from_py_func' in module 'tensorflow.python.framework.func_graph'
# ----------------------------debug func_graph.py 1267
# The caller function is 'wrapped_fn' in module 'tensorflow.python.eager.def_function'
# ----------------------------debug api.py 321
# The caller function is 'autograph_handler' in module 'tensorflow.python.framework.func_graph'
# ----------------------------debug api.py 321
# The caller function is 'tf__train_function' in module '__autograph_generated_fileis5milz0'
# ----------------------------debug api.py 451
# The caller function is 'converted_call' in module 'tensorflow.python.autograph.impl.api'
# ----------------------------debug api.py 321
# The caller function is 'wrapper' in module 'tensorflow.python.autograph.impl.api'
# ----------------------------debug api.py 451
# The caller function is 'converted_call' in module 'tensorflow.python.autograph.impl.api'
# ----------------------------debug training.py 1167
# The caller function is '_call_unconverted' in module 'tensorflow.python.autograph.impl.api'
# ----------------------------debug training.py 991
# The caller function is 'run_step' in module 'keras.engine.training'
# ----------------------------debug base_layer.py 983
# str(self.name): model_1
# The caller function is 'error_handler' in module 'keras.utils.traceback_utils' (current in base_layer.py 989)
# args: (<tf.Tensor 'IteratorGetNext:0' shape=(None, 1) dtype=float32>,)
# kwargs: {'training': True}
# ----------------------------debug base_layer.py 1009
# ----------------------------debug base_layer.py 1011
# ----------------------------debug base_layer.py 1013
# ----------------------------debug base_layer.py 1048
# ----------------------------debug base_layer.py 1112
# inputs: Tensor("IteratorGetNext:0", shape=(None, 1), dtype=float32)
# ----------------------------debug traceback_utils.py 101
# The caller function is '__call__' in module 'keras.engine.base_layer' (current in base_layer.py 989)
# ----------------------------debug base_layer.py 983
# str(self.name): lambda_1
# The caller function is 'error_handler' in module 'keras.utils.traceback_utils' (current in base_layer.py 989)
# args: (<tf.Tensor 'IteratorGetNext:0' shape=(None, 1) dtype=float32>,)
# kwargs: {}
# ----------------------------debug base_layer.py 1009
# ----------------------------debug base_layer.py 1011
# ----------------------------debug base_layer.py 1013
# ----------------------------debug base_layer.py 1048
# ----------------------------debug base_layer.py 1112
# inputs: Tensor("IteratorGetNext:0", shape=(None, 1), dtype=float32)
# ----------------------------debug traceback_utils.py 101
# The caller function is '__call__' in module 'keras.engine.base_layer' (current in base_layer.py 989)
# outputs: Tensor("model_1/lambda_1/mul:0", shape=(None, 1), dtype=float32)
# outputs: Tensor("model_1/lambda_1/mul:0", shape=(None, 1), dtype=float32)
# ----------------------------debug api.py 321
# The caller function is 'wrapper' in module 'tensorflow.python.autograph.impl.api'
# ----------------------------debug api.py 451
# The caller function is 'converted_call' in module 'tensorflow.python.autograph.impl.api'
# ----------------------------debug api.py 321
# The caller function is 'wrapper' in module 'tensorflow.python.autograph.impl.api'
# ----------------------------debug api.py 451
# The caller function is 'converted_call' in module 'tensorflow.python.autograph.impl.api'
# ----------------------------debug base_metric.py 503
# The caller function is '_call_unconverted' in module 'tensorflow.python.autograph.impl.api'
# values: Tensor("Mul:0", shape=(), dtype=float32)
# ----------------------------debug training.py 996
# ----------------------------debug training.py 998
# loss: Tensor("mean_squared_error/weighted_loss/value:0", shape=(), dtype=float32)
# tf.executing_eagerly(): False
# tf.__version__: 2.10.0
# type(loss): <class 'tensorflow.python.framework.ops.Tensor'>
# env_var: _DeviceAttributes(/job:localhost/replica:0/task:0/device:CPU:0, CPU, 268435456, 5714291194449777323)
# x: Tensor("IteratorGetNext:0", shape=(None, 1), dtype=float32)
# y: Tensor("IteratorGetNext:1", shape=(None, 1), dtype=float32)
# y_pred: Tensor("model_1/lambda_1/mul:0", shape=(None, 1), dtype=float32)
# self.trainable_variables: []
# ----------------------------debug optimizer_v2.py 639
# The caller function is 'minimize' in module 'keras.optimizers.optimizer_v2.optimizer_v2'
# var_list: []
# tape: <tensorflow.python.eager.backprop.GradientTape object at 0x00000181001AAFB0>
# loss: Tensor("mean_squared_error/weighted_loss/value:0", shape=(), dtype=float32)
# ----------------------------debug optimizer_v2.py 511
# loss type: <class 'tensorflow.python.framework.ops.Tensor'>
# loss dir: ['OVERLOADABLE_OPERATORS', '_USE_EQUALITY', '__abs__', '__add__', '__and__', '__annotations__', '__array__', '__array_priority__', '__bool__', '__class__', '__copy__', '__delattr__', '__dict__', '__dir__', '__div__', '__doc__', '__eq__', '__floordiv__', '__format__', '__ge__', '__getattr__', '__getattribute__', '__getitem__', '__gt__', '__hash__', '__init__', '__init_subclass__', '__invert__', '__iter__', '__le__', '__len__', '__lt__', '__matmul__', '__mod__', '__module__', '__mul__', '__ne__', '__neg__', '__new__', '__nonzero__', '__or__', '__pow__', '__radd__', '__rand__', '__rdiv__', '__reduce__', '__reduce_ex__', '__repr__', '__rfloordiv__', '__rmatmul__', '__rmod__', '__rmul__', '__ror__', '__round__', '__rpow__', '__rsub__', '__rtruediv__', '__rxor__', '__setattr__', '__sizeof__', '__str__', '__sub__', '__subclasshook__', '__tf_tracing_type__', '__truediv__', '__weakref__', '__xor__', '_as_node_def_input', '_as_tf_output', '_c_api_shape', '_consumers', '_create_with_tf_output', '_disallow_bool_casting', '_disallow_in_graph_mode', '_disallow_iteration', '_disallow_when_autograph_disabled', '_disallow_when_autograph_enabled', '_disallow_when_autograph_unavailable', '_dtype', '_id', '_matmul', '_name', '_numpy_style_getitem', '_op', '_override_operator', '_rank', '_shape', '_shape_as_list', '_shape_tuple', '_shape_val', '_tf_api_names', '_tf_api_names_v1', '_tf_output', '_value_index', '_with_index_add', '_with_index_max', '_with_index_min', '_with_index_update', 'consumers', 'device', 'dtype', 'eval', 'experimental_ref', 'get_shape', 'graph', 'name', 'op', 'ref', 'set_shape', 'shape', 'value_index']
# loss consumers: [<tf.Operation 'Mul' type=Mul>, <tf.Operation 'Adam/gradients/mul' type=Mul>]
# loss device:
# WARNING:tensorflow:From C:\Users\zhhua\OneDrive\Desktop\PythonProgram\CAT\Mask_R_CNN\Mask_RCNN\keras\optimizers\optimizer_v2\optimizer_v2.py:539: Tensor.experimental_ref (from tensorflow.python.framework.ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use ref() instead.
# loss experimental_ref: <Reference wrapping <tf.Tensor 'mean_squared_error/weighted_loss/value:0' shape=() dtype=float32>>
# loss get_shape: ()
# loss name: mean_squared_error/weighted_loss/value:0
# The caller function is '_compute_gradients' in module 'keras.optimizers.optimizer_v2.optimizer_v2'
# graph name: iterator
# []
# graph name: IteratorGetNext
# []
# graph name: model_1/lambda_1/mul/y
# []
# graph name: model_1/lambda_1/mul
# []
# graph name: mean_squared_error/SquaredDifference
# []
# graph name: mean_squared_error/Mean/reduction_indices
# []
# graph name: mean_squared_error/Mean
# []
# graph name: mean_squared_error/weighted_loss/Const
# []
# graph name: mean_squared_error/weighted_loss/Mul
# []
# graph name: mean_squared_error/weighted_loss/Const_1
# []
# graph name: mean_squared_error/weighted_loss/Sum
# []
# graph name: mean_squared_error/weighted_loss/num_elements
# []
# graph name: mean_squared_error/weighted_loss/num_elements/Cast
# []
# graph name: mean_squared_error/weighted_loss/Rank
# []
# graph name: mean_squared_error/weighted_loss/range/start
# []
# graph name: mean_squared_error/weighted_loss/range/delta
# []
# graph name: mean_squared_error/weighted_loss/range
# []
# graph name: mean_squared_error/weighted_loss/Sum_1
# []
# graph name: mean_squared_error/weighted_loss/value
# []
# graph name: Shape
# []
# graph name: strided_slice/stack
# []
# graph name: strided_slice/stack_1
# []
# graph name: strided_slice/stack_2
# []
# graph name: strided_slice
# []
# graph name: Cast
# []
# graph name: Mul
# []
# graph name: Rank
# []
# graph name: range/start
# []
# graph name: range/delta
# []
# graph name: range
# []
# graph name: Sum
# []
# graph name: AssignAddVariableOp/resource
# []
# graph name: AssignAddVariableOp
# []
# graph name: Rank_1
# []
# graph name: range_1/start
# []
# graph name: range_1/delta
# []
# graph name: range_1
# []
# graph name: Sum_1
# []
# graph name: AssignAddVariableOp_1/resource
# []
# graph name: AssignAddVariableOp_1
# []
# graph name: Adam/gradients/mul/y
# []
# graph name: Adam/gradients/mul
# []
# grads: []
# var_list: []
# grad_loss: None
# ----------------------------debug optimizer_v2.py 579
# The caller function is 'train_step' in module 'keras.engine.training'
# ----------------------------debug optimizer_v2.py 689
# The caller function is 'minimize' in module 'keras.optimizers.optimizer_v2.optimizer_v2'
# ----------------------------debug utils.py 62
# grads_and_vars: []
# The caller function is 'apply_gradients' in module 'keras.optimizers.optimizer_v2.optimizer_v2' (current in utils.py 68)
# ----------------------------debug api.py 321
# The caller function is 'wrapper' in module 'tensorflow.python.autograph.impl.api'
# ----------------------------debug api.py 451
# The caller function is 'converted_call' in module 'tensorflow.python.autograph.impl.api'
# ----------------------------debug function.py 2654
# The caller function is '_maybe_define_function' in module 'tensorflow.python.eager.function'
# ----------------------------debug func_graph.py 1187
# The caller function is '_create_graph_function' in module 'tensorflow.python.eager.function'
# ----------------------------debug def_function.py 672
# The caller function is 'func_graph_from_py_func' in module 'tensorflow.python.framework.func_graph'
# ----------------------------debug func_graph.py 1267
# The caller function is 'wrapped_fn' in module 'tensorflow.python.eager.def_function'
# ----------------------------debug api.py 321
# The caller function is 'autograph_handler' in module 'tensorflow.python.framework.func_graph'
# ----------------------------debug api.py 321
# The caller function is 'tf__train_function' in module '__autograph_generated_fileis5milz0'
# ----------------------------debug api.py 451
# The caller function is 'converted_call' in module 'tensorflow.python.autograph.impl.api'
# ----------------------------debug api.py 321
# The caller function is 'wrapper' in module 'tensorflow.python.autograph.impl.api'
# ----------------------------debug api.py 451
# The caller function is 'converted_call' in module 'tensorflow.python.autograph.impl.api'
# ----------------------------debug training.py 1167
# The caller function is '_call_unconverted' in module 'tensorflow.python.autograph.impl.api'
# ----------------------------debug training.py 991
# The caller function is 'run_step' in module 'keras.engine.training'
# ----------------------------debug base_layer.py 983
# str(self.name): model_1
# The caller function is 'error_handler' in module 'keras.utils.traceback_utils' (current in base_layer.py 989)
# args: (<tf.Tensor 'IteratorGetNext:0' shape=(None, 1) dtype=float32>,)
# kwargs: {'training': True}
# ----------------------------debug base_layer.py 1009
# ----------------------------debug base_layer.py 1011
# ----------------------------debug base_layer.py 1013
# ----------------------------debug base_layer.py 1048
# ----------------------------debug base_layer.py 1112
# inputs: Tensor("IteratorGetNext:0", shape=(None, 1), dtype=float32)
# ----------------------------debug traceback_utils.py 101
# The caller function is '__call__' in module 'keras.engine.base_layer' (current in base_layer.py 989)
# ----------------------------debug base_layer.py 983
# str(self.name): lambda_1
# The caller function is 'error_handler' in module 'keras.utils.traceback_utils' (current in base_layer.py 989)
# args: (<tf.Tensor 'IteratorGetNext:0' shape=(None, 1) dtype=float32>,)
# kwargs: {}
# ----------------------------debug base_layer.py 1009
# ----------------------------debug base_layer.py 1011
# ----------------------------debug base_layer.py 1013
# ----------------------------debug base_layer.py 1048
# ----------------------------debug base_layer.py 1112
# inputs: Tensor("IteratorGetNext:0", shape=(None, 1), dtype=float32)
# ----------------------------debug traceback_utils.py 101
# The caller function is '__call__' in module 'keras.engine.base_layer' (current in base_layer.py 989)
# outputs: Tensor("model_1/lambda_1/mul:0", shape=(None, 1), dtype=float32)
# outputs: Tensor("model_1/lambda_1/mul:0", shape=(None, 1), dtype=float32)
# ----------------------------debug api.py 321
# The caller function is 'wrapper' in module 'tensorflow.python.autograph.impl.api'
# ----------------------------debug api.py 451
# The caller function is 'converted_call' in module 'tensorflow.python.autograph.impl.api'
# ----------------------------debug api.py 321
# The caller function is 'wrapper' in module 'tensorflow.python.autograph.impl.api'
# ----------------------------debug api.py 451
# The caller function is 'converted_call' in module 'tensorflow.python.autograph.impl.api'
# ----------------------------debug base_metric.py 503
# The caller function is '_call_unconverted' in module 'tensorflow.python.autograph.impl.api'
# values: Tensor("Mul:0", shape=(), dtype=float32)
# ----------------------------debug training.py 996
# ----------------------------debug training.py 998
# loss: Tensor("mean_squared_error/weighted_loss/value:0", shape=(), dtype=float32)
# tf.executing_eagerly(): False
# tf.__version__: 2.10.0
# type(loss): <class 'tensorflow.python.framework.ops.Tensor'>
# env_var: _DeviceAttributes(/job:localhost/replica:0/task:0/device:CPU:0, CPU, 268435456, -7504526946273113179)
# x: Tensor("IteratorGetNext:0", shape=(None, 1), dtype=float32)
# y: Tensor("IteratorGetNext:1", shape=(None, 1), dtype=float32)
# y_pred: Tensor("model_1/lambda_1/mul:0", shape=(None, 1), dtype=float32)
# self.trainable_variables: []
# ----------------------------debug optimizer_v2.py 639
# The caller function is 'minimize' in module 'keras.optimizers.optimizer_v2.optimizer_v2'
# var_list: []
# tape: <tensorflow.python.eager.backprop.GradientTape object at 0x00000181002406A0>
# loss: Tensor("mean_squared_error/weighted_loss/value:0", shape=(), dtype=float32)
# ----------------------------debug optimizer_v2.py 511
# loss type: <class 'tensorflow.python.framework.ops.Tensor'>
# loss dir: ['OVERLOADABLE_OPERATORS', '_USE_EQUALITY', '__abs__', '__add__', '__and__', '__annotations__', '__array__', '__array_priority__', '__bool__', '__class__', '__copy__', '__delattr__', '__dict__', '__dir__', '__div__', '__doc__', '__eq__', '__floordiv__', '__format__', '__ge__', '__getattr__', '__getattribute__', '__getitem__', '__gt__', '__hash__', '__init__', '__init_subclass__', '__invert__', '__iter__', '__le__', '__len__', '__lt__', '__matmul__', '__mod__', '__module__', '__mul__', '__ne__', '__neg__', '__new__', '__nonzero__', '__or__', '__pow__', '__radd__', '__rand__', '__rdiv__', '__reduce__', '__reduce_ex__', '__repr__', '__rfloordiv__', '__rmatmul__', '__rmod__', '__rmul__', '__ror__', '__round__', '__rpow__', '__rsub__', '__rtruediv__', '__rxor__', '__setattr__', '__sizeof__', '__str__', '__sub__', '__subclasshook__', '__tf_tracing_type__', '__truediv__', '__weakref__', '__xor__', '_as_node_def_input', '_as_tf_output', '_c_api_shape', '_consumers', '_create_with_tf_output', '_disallow_bool_casting', '_disallow_in_graph_mode', '_disallow_iteration', '_disallow_when_autograph_disabled', '_disallow_when_autograph_enabled', '_disallow_when_autograph_unavailable', '_dtype', '_id', '_matmul', '_name', '_numpy_style_getitem', '_op', '_override_operator', '_rank', '_shape', '_shape_as_list', '_shape_tuple', '_shape_val', '_tf_api_names', '_tf_api_names_v1', '_tf_output', '_value_index', '_with_index_add', '_with_index_max', '_with_index_min', '_with_index_update', 'consumers', 'device', 'dtype', 'eval', 'experimental_ref', 'get_shape', 'graph', 'name', 'op', 'ref', 'set_shape', 'shape', 'value_index']
# loss consumers: [<tf.Operation 'Mul' type=Mul>, <tf.Operation 'Adam/gradients/mul' type=Mul>]
# loss device:
# loss experimental_ref: <Reference wrapping <tf.Tensor 'mean_squared_error/weighted_loss/value:0' shape=() dtype=float32>>
# loss get_shape: ()
# loss name: mean_squared_error/weighted_loss/value:0
# The caller function is '_compute_gradients' in module 'keras.optimizers.optimizer_v2.optimizer_v2'
# graph name: iterator
# []
# graph name: IteratorGetNext
# []
# graph name: model_1/lambda_1/mul/y
# []
# graph name: model_1/lambda_1/mul
# []
# graph name: mean_squared_error/SquaredDifference
# []
# graph name: mean_squared_error/Mean/reduction_indices
# []
# graph name: mean_squared_error/Mean
# []
# graph name: mean_squared_error/weighted_loss/Const
# []
# graph name: mean_squared_error/weighted_loss/Mul
# []
# graph name: mean_squared_error/weighted_loss/Const_1
# []
# graph name: mean_squared_error/weighted_loss/Sum
# []
# graph name: mean_squared_error/weighted_loss/num_elements
# []
# graph name: mean_squared_error/weighted_loss/num_elements/Cast
# []
# graph name: mean_squared_error/weighted_loss/Rank
# []
# graph name: mean_squared_error/weighted_loss/range/start
# []
# graph name: mean_squared_error/weighted_loss/range/delta
# []
# graph name: mean_squared_error/weighted_loss/range
# []
# graph name: mean_squared_error/weighted_loss/Sum_1
# []
# graph name: mean_squared_error/weighted_loss/value
# []
# graph name: Shape
# []
# graph name: strided_slice/stack
# []
# graph name: strided_slice/stack_1
# []
# graph name: strided_slice/stack_2
# []
# graph name: strided_slice
# []
# graph name: Cast
# []
# graph name: Mul
# []
# graph name: Rank
# []
# graph name: range/start
# []
# graph name: range/delta
# []
# graph name: range
# []
# graph name: Sum
# []
# graph name: AssignAddVariableOp/resource
# []
# graph name: AssignAddVariableOp
# []
# graph name: Rank_1
# []
# graph name: range_1/start
# []
# graph name: range_1/delta
# []
# graph name: range_1
# []
# graph name: Sum_1
# []
# graph name: AssignAddVariableOp_1/resource
# []
# graph name: AssignAddVariableOp_1
# []
# graph name: Adam/gradients/mul/y
# []
# graph name: Adam/gradients/mul
# []
# grads: []
# var_list: []
# grad_loss: None
# ----------------------------debug optimizer_v2.py 579
# The caller function is 'train_step' in module 'keras.engine.training'
# ----------------------------debug optimizer_v2.py 689
# The caller function is 'minimize' in module 'keras.optimizers.optimizer_v2.optimizer_v2'
# ----------------------------debug utils.py 62
# grads_and_vars: []
# The caller function is 'apply_gradients' in module 'keras.optimizers.optimizer_v2.optimizer_v2' (current in utils.py 68)
# ----------------------------debug api.py 321
# The caller function is 'wrapper' in module 'tensorflow.python.autograph.impl.api'
# ----------------------------debug api.py 451
# The caller function is 'converted_call' in module 'tensorflow.python.autograph.impl.api'
# 1/1 [==============================] - 0s 187ms/step - loss: 0.0000e+00
# Epoch 2/100
# 1/1 [==============================] - 0s 7ms/step - loss: 0.0000e+00
# Epoch 3/100
# 1/1 [==============================] - 0s 3ms/step - loss: 0.0000e+00
# Epoch 4/100
# 1/1 [==============================] - 0s 3ms/step - loss: 0.0000e+00
# Epoch 5/100
# 1/1 [==============================] - 0s 2ms/step - loss: 0.0000e+00
# Epoch 6/100
# 1/1 [==============================] - 0s 2ms/step - loss: 0.0000e+00
# Epoch 7/100
# 1/1 [==============================] - 0s 957us/step - loss: 0.0000e+00
# Epoch 8/100
# 1/1 [==============================] - 0s 5ms/step - loss: 0.0000e+00
# Epoch 9/100
# 1/1 [==============================] - 0s 0s/step - loss: 0.0000e+00
# Epoch 10/100
# 1/1 [==============================] - 0s 5ms/step - loss: 0.0000e+00
# Epoch 11/100
# 1/1 [==============================] - 0s 1ms/step - loss: 0.0000e+00
# Epoch 12/100
# 1/1 [==============================] - 0s 5ms/step - loss: 0.0000e+00
# Epoch 13/100
# 1/1 [==============================] - 0s 2ms/step - loss: 0.0000e+00
# Epoch 14/100
# 1/1 [==============================] - 0s 0s/step - loss: 0.0000e+00
# Epoch 15/100
# 1/1 [==============================] - 0s 3ms/step - loss: 0.0000e+00
# Epoch 16/100
# 1/1 [==============================] - 0s 0s/step - loss: 0.0000e+00
# Epoch 17/100
# 1/1 [==============================] - 0s 3ms/step - loss: 0.0000e+00
# Epoch 18/100
# 1/1 [==============================] - 0s 0s/step - loss: 0.0000e+00
# Epoch 19/100
# 1/1 [==============================] - 0s 7ms/step - loss: 0.0000e+00
# Epoch 20/100
# 1/1 [==============================] - 0s 0s/step - loss: 0.0000e+00
# Epoch 21/100
# 1/1 [==============================] - 0s 6ms/step - loss: 0.0000e+00
# Epoch 22/100
# 1/1 [==============================] - 0s 0s/step - loss: 0.0000e+00
# Epoch 23/100
# 1/1 [==============================] - 0s 5ms/step - loss: 0.0000e+00
# Epoch 24/100
# 1/1 [==============================] - 0s 2ms/step - loss: 0.0000e+00
# Epoch 25/100
# 1/1 [==============================] - 0s 3ms/step - loss: 0.0000e+00
# Epoch 26/100
# 1/1 [==============================] - 0s 4ms/step - loss: 0.0000e+00
# Epoch 27/100
# 1/1 [==============================] - 0s 3ms/step - loss: 0.0000e+00
# Epoch 28/100
# 1/1 [==============================] - 0s 0s/step - loss: 0.0000e+00
# Epoch 29/100
# 1/1 [==============================] - 0s 7ms/step - loss: 0.0000e+00
# Epoch 30/100
# 1/1 [==============================] - 0s 0s/step - loss: 0.0000e+00
# Epoch 31/100
# 1/1 [==============================] - 0s 2ms/step - loss: 0.0000e+00
# Epoch 32/100
# 1/1 [==============================] - 0s 0s/step - loss: 0.0000e+00
# Epoch 33/100
# 1/1 [==============================] - 0s 7ms/step - loss: 0.0000e+00
# Epoch 34/100
# 1/1 [==============================] - 0s 0s/step - loss: 0.0000e+00
# Epoch 35/100
# 1/1 [==============================] - 0s 7ms/step - loss: 0.0000e+00
# Epoch 36/100
# 1/1 [==============================] - 0s 0s/step - loss: 0.0000e+00
# Epoch 37/100
# 1/1 [==============================] - 0s 2ms/step - loss: 0.0000e+00
# Epoch 38/100
# 1/1 [==============================] - 0s 0s/step - loss: 0.0000e+00
# Epoch 39/100
# 1/1 [==============================] - 0s 2ms/step - loss: 0.0000e+00
# Epoch 40/100
# 1/1 [==============================] - 0s 0s/step - loss: 0.0000e+00
# Epoch 41/100
# 1/1 [==============================] - 0s 5ms/step - loss: 0.0000e+00
# Epoch 42/100
# 1/1 [==============================] - 0s 0s/step - loss: 0.0000e+00
# Epoch 43/100
# 1/1 [==============================] - 0s 5ms/step - loss: 0.0000e+00
# Epoch 44/100
# 1/1 [==============================] - 0s 2ms/step - loss: 0.0000e+00
# Epoch 45/100
# 1/1 [==============================] - 0s 4ms/step - loss: 0.0000e+00
# Epoch 46/100
# 1/1 [==============================] - 0s 0s/step - loss: 0.0000e+00
# Epoch 47/100
# 1/1 [==============================] - 0s 5ms/step - loss: 0.0000e+00
# Epoch 48/100
# 1/1 [==============================] - 0s 0s/step - loss: 0.0000e+00
# Epoch 49/100
# 1/1 [==============================] - 0s 5ms/step - loss: 0.0000e+00
# Epoch 50/100
# 1/1 [==============================] - 0s 0s/step - loss: 0.0000e+00
# Epoch 51/100
# 1/1 [==============================] - 0s 6ms/step - loss: 0.0000e+00
# Epoch 52/100
# 1/1 [==============================] - 0s 998us/step - loss: 0.0000e+00
# Epoch 53/100
# 1/1 [==============================] - 0s 5ms/step - loss: 0.0000e+00
# Epoch 54/100
# 1/1 [==============================] - 0s 0s/step - loss: 0.0000e+00
# Epoch 55/100
# 1/1 [==============================] - 0s 3ms/step - loss: 0.0000e+00
# Epoch 56/100
# 1/1 [==============================] - 0s 0s/step - loss: 0.0000e+00
# Epoch 57/100
# 1/1 [==============================] - 0s 3ms/step - loss: 0.0000e+00
# Epoch 58/100
# 1/1 [==============================] - 0s 0s/step - loss: 0.0000e+00
# Epoch 59/100
# 1/1 [==============================] - 0s 2ms/step - loss: 0.0000e+00
# Epoch 60/100
# 1/1 [==============================] - 0s 0s/step - loss: 0.0000e+00
# Epoch 61/100
# 1/1 [==============================] - 0s 3ms/step - loss: 0.0000e+00
# Epoch 62/100
# 1/1 [==============================] - 0s 0s/step - loss: 0.0000e+00
# Epoch 63/100
# 1/1 [==============================] - 0s 2ms/step - loss: 0.0000e+00
# Epoch 64/100
# 1/1 [==============================] - 0s 0s/step - loss: 0.0000e+00
# Epoch 65/100
# 1/1 [==============================] - 0s 2ms/step - loss: 0.0000e+00
# Epoch 66/100
# 1/1 [==============================] - 0s 0s/step - loss: 0.0000e+00
# Epoch 67/100
# 1/1 [==============================] - 0s 3ms/step - loss: 0.0000e+00
# Epoch 68/100
# 1/1 [==============================] - 0s 0s/step - loss: 0.0000e+00
# Epoch 69/100
# 1/1 [==============================] - 0s 2ms/step - loss: 0.0000e+00
# Epoch 70/100
# 1/1 [==============================] - 0s 3ms/step - loss: 0.0000e+00
# Epoch 71/100
# 1/1 [==============================] - 0s 2ms/step - loss: 0.0000e+00
# Epoch 72/100
# 1/1 [==============================] - 0s 3ms/step - loss: 0.0000e+00
# Epoch 73/100
# 1/1 [==============================] - 0s 2ms/step - loss: 0.0000e+00
# Epoch 74/100
# 1/1 [==============================] - 0s 680us/step - loss: 0.0000e+00
# Epoch 75/100
# 1/1 [==============================] - 0s 4ms/step - loss: 0.0000e+00
# Epoch 76/100
# 1/1 [==============================] - 0s 0s/step - loss: 0.0000e+00
# Epoch 77/100
# 1/1 [==============================] - 0s 5ms/step - loss: 0.0000e+00
# Epoch 78/100
# 1/1 [==============================] - 0s 0s/step - loss: 0.0000e+00
# Epoch 79/100
# 1/1 [==============================] - 0s 5ms/step - loss: 0.0000e+00
# Epoch 80/100
# 1/1 [==============================] - 0s 0s/step - loss: 0.0000e+00
# Epoch 81/100
# 1/1 [==============================] - 0s 7ms/step - loss: 0.0000e+00
# Epoch 82/100
# 1/1 [==============================] - 0s 0s/step - loss: 0.0000e+00
# Epoch 83/100
# 1/1 [==============================] - 0s 3ms/step - loss: 0.0000e+00
# Epoch 84/100
# 1/1 [==============================] - 0s 0s/step - loss: 0.0000e+00
# Epoch 85/100
# 1/1 [==============================] - 0s 3ms/step - loss: 0.0000e+00
# Epoch 86/100
# 1/1 [==============================] - 0s 0s/step - loss: 0.0000e+00
# Epoch 87/100
# 1/1 [==============================] - 0s 6ms/step - loss: 0.0000e+00
# Epoch 88/100
# 1/1 [==============================] - 0s 0s/step - loss: 0.0000e+00
# Epoch 89/100
# 1/1 [==============================] - 0s 2ms/step - loss: 0.0000e+00
# Epoch 90/100
# 1/1 [==============================] - 0s 0s/step - loss: 0.0000e+00
# Epoch 91/100
# 1/1 [==============================] - 0s 5ms/step - loss: 0.0000e+00
# Epoch 92/100
# 1/1 [==============================] - 0s 4ms/step - loss: 0.0000e+00
# Epoch 93/100
# 1/1 [==============================] - 0s 2ms/step - loss: 0.0000e+00
# Epoch 94/100
# 1/1 [==============================] - 0s 2ms/step - loss: 0.0000e+00
# Epoch 95/100
# 1/1 [==============================] - 0s 2ms/step - loss: 0.0000e+00
# Epoch 96/100
# 1/1 [==============================] - 0s 2ms/step - loss: 0.0000e+00
# Epoch 97/100
# 1/1 [==============================] - 0s 3ms/step - loss: 0.0000e+00
# Epoch 98/100
# 1/1 [==============================] - 0s 2ms/step - loss: 0.0000e+00
# Epoch 99/100
# 1/1 [==============================] - 0s 0s/step - loss: 0.0000e+00
# Epoch 100/100
# 1/1 [==============================] - 0s 2ms/step - loss: 0.0000e+00
# ----------------------------debug function.py 2654
# The caller function is '_maybe_define_function' in module 'tensorflow.python.eager.function'
# ----------------------------debug func_graph.py 1187
# The caller function is '_create_graph_function' in module 'tensorflow.python.eager.function'
# ----------------------------debug api.py 321
# The caller function is 'wrapper' in module 'tensorflow.python.autograph.impl.api'
# ----------------------------debug api.py 451
# The caller function is 'converted_call' in module 'tensorflow.python.autograph.impl.api'
# ----------------------------debug function.py 2654
# The caller function is '_maybe_define_function' in module 'tensorflow.python.eager.function'
# ----------------------------debug func_graph.py 1187
# The caller function is '_create_graph_function' in module 'tensorflow.python.eager.function'
# ----------------------------debug api.py 321
# The caller function is 'wrapper' in module 'tensorflow.python.autograph.impl.api'
# ----------------------------debug api.py 451
# The caller function is 'converted_call' in module 'tensorflow.python.autograph.impl.api'
# ----------------------------debug function.py 2654
# The caller function is '_maybe_define_function' in module 'tensorflow.python.eager.function'
# ----------------------------debug func_graph.py 1187
# The caller function is '_create_graph_function' in module 'tensorflow.python.eager.function'
# ----------------------------debug api.py 321
# The caller function is 'wrapper' in module 'tensorflow.python.autograph.impl.api'
# ----------------------------debug api.py 451
# The caller function is 'converted_call' in module 'tensorflow.python.autograph.impl.api'
# ----------------------------debug def_function.py 755
# The caller function is '_call' in module 'tensorflow.python.eager.def_function'
# ----------------------------debug function.py 2520
# The caller function is '_initialize' in module 'tensorflow.python.eager.def_function'
# ----------------------------debug function.py 2654
# The caller function is '_maybe_define_function' in module 'tensorflow.python.eager.function'
# ----------------------------debug func_graph.py 1187
# The caller function is '_create_graph_function' in module 'tensorflow.python.eager.function'
# ----------------------------debug def_function.py 672
# The caller function is 'func_graph_from_py_func' in module 'tensorflow.python.framework.func_graph'
# ----------------------------debug func_graph.py 1267
# The caller function is 'wrapped_fn' in module 'tensorflow.python.eager.def_function'
# ----------------------------debug api.py 321
# The caller function is 'autograph_handler' in module 'tensorflow.python.framework.func_graph'
# ----------------------------debug api.py 321
# The caller function is 'tf__test_function' in module '__autograph_generated_fileb0om7hvf'
# ----------------------------debug api.py 451
# The caller function is 'converted_call' in module 'tensorflow.python.autograph.impl.api'
# ----------------------------debug api.py 321
# The caller function is 'wrapper' in module 'tensorflow.python.autograph.impl.api'
# ----------------------------debug api.py 451
# The caller function is 'converted_call' in module 'tensorflow.python.autograph.impl.api'
# ----------------------------debug base_layer.py 983
# str(self.name): model_1
# The caller function is 'error_handler' in module 'keras.utils.traceback_utils' (current in base_layer.py 989)
# args: (<tf.Tensor 'IteratorGetNext:0' shape=(None, 1) dtype=float32>,)
# kwargs: {'training': False}
# ----------------------------debug base_layer.py 1009
# ----------------------------debug base_layer.py 1011
# ----------------------------debug base_layer.py 1013
# ----------------------------debug base_layer.py 1048
# ----------------------------debug base_layer.py 1112
# inputs: Tensor("IteratorGetNext:0", shape=(None, 1), dtype=float32)
# ----------------------------debug traceback_utils.py 101
# The caller function is '__call__' in module 'keras.engine.base_layer' (current in base_layer.py 989)
# ----------------------------debug base_layer.py 983
# str(self.name): lambda_1
# The caller function is 'error_handler' in module 'keras.utils.traceback_utils' (current in base_layer.py 989)
# args: (<tf.Tensor 'IteratorGetNext:0' shape=(None, 1) dtype=float32>,)
# kwargs: {}
# ----------------------------debug base_layer.py 1009
# ----------------------------debug base_layer.py 1011
# ----------------------------debug base_layer.py 1013
# ----------------------------debug base_layer.py 1048
# ----------------------------debug base_layer.py 1112
# inputs: Tensor("IteratorGetNext:0", shape=(None, 1), dtype=float32)
# ----------------------------debug traceback_utils.py 101
# The caller function is '__call__' in module 'keras.engine.base_layer' (current in base_layer.py 989)
# outputs: Tensor("model_1/lambda_1/mul:0", shape=(None, 1), dtype=float32)
# outputs: Tensor("model_1/lambda_1/mul:0", shape=(None, 1), dtype=float32)
# ----------------------------debug api.py 321
# The caller function is 'wrapper' in module 'tensorflow.python.autograph.impl.api'
# ----------------------------debug api.py 451
# The caller function is 'converted_call' in module 'tensorflow.python.autograph.impl.api'
# ----------------------------debug api.py 321
# The caller function is 'wrapper' in module 'tensorflow.python.autograph.impl.api'
# ----------------------------debug api.py 451
# The caller function is 'converted_call' in module 'tensorflow.python.autograph.impl.api'
# ----------------------------debug base_metric.py 503
# The caller function is '_call_unconverted' in module 'tensorflow.python.autograph.impl.api'
# values: Tensor("Mul:0", shape=(), dtype=float32)
# ----------------------------debug api.py 321
# The caller function is 'wrapper' in module 'tensorflow.python.autograph.impl.api'
# ----------------------------debug api.py 451
# The caller function is 'converted_call' in module 'tensorflow.python.autograph.impl.api'
# 1/1 [==============================] - 0s 106ms/step - loss: 0.0000e+00
# Final loss: 0.0

# %%
import tensorflow as tf
tf.config.list_physical_devices('GPU')
# Out:
# [PhysicalDevice(name='/physical_device:GPU:0', device_type='GPU')]
